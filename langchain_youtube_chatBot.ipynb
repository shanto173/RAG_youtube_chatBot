# %%
# Set OpenAI API Key
from google.colab import userdata
import os

# Get your key securely (no need to type it)
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# ✅ Optional: check if it’s loaded
print("✅ OpenAI API key loaded successfully!" if os.environ.get("OPENAI_API_KEY") else "❌ Key not found")
print("✓ OpenAI API configured successfully!")
print(f"✓ Using model: gpt-4o-mini")
# Out:
# ✅ OpenAI API key loaded successfully!
# ✓ OpenAI API configured successfully!
# ✓ Using model: gpt-4o-mini

# %%
# !pip install numpy pandas pydantic scikit-learn xgboost imbalanced-learn langchain openai tqdm langchain_openai youtube-transcript-api langchain-community faiss-cpu tiktoken python-dotenv
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (2.11.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.1)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.12/dist-packages (0.3.35)
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.3.31)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic) (0.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.38)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# !pip install youtube-transcript-api --upgrade

# %% [markdown]
# # Step 1a - Indexing (Document Ingestion)

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
import pandas as pd

VIDEO_URL = "https://www.youtube.com/watch?v=Gfr50f6ZBvo"

def get_video_id(url: str) -> str:
    if "v=" in url:
        return url.split("v=")[1].split("&")[0]
    elif "youtu.be/" in url:
        return url.split("youtu.be/")[1].split("?")[0]
    else:
        raise ValueError("Invalid YouTube URL format.")

video_id = get_video_id(VIDEO_URL)

try:
    yt_api = YouTubeTranscriptApi()
    # Try fetching in English first, fallback to Hindi (auto-generated)
    transcript_snippets = yt_api.fetch(video_id, languages=["en", "hi"])

    # Convert snippet objects to text
    texts = [snippet.text.strip() for snippet in transcript_snippets if snippet.text.strip()]
    full_transcript = " ".join(texts)

except TranscriptsDisabled:
    print("❌ Captions are disabled for this video.")
    full_transcript = ""
except Exception as e:
    print(f"⚠️ Could not fetch transcript: {e}")
    full_transcript = ""

# ===========================
# PREVIEW
# ===========================
if full_transcript:
    df = pd.DataFrame([{"video_id": video_id, "transcript": full_transcript}])

print("\n--- TRANSCRIPT PREVIEW ---")
print(full_transcript[:1000] + "..." if full_transcript else "No transcript available.")

transcript = full_transcript
# Out:
# --- TRANSCRIPT PREVIEW ---
# the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough ...

# %%
transcript_snippets.to_raw_data()
# Out:
# [{'text': 'the following is a conversation with',
#   'start': 0.08,
#   'duration': 3.44},
#  {'text': 'demus hasabis', 'start': 1.76, 'duration': 4.96},
#  {'text': 'ceo and co-founder of deepmind', 'start': 3.52, 'duration': 5.119},
#  {'text': 'a company that has published and builds',
#   'start': 6.72,
#   'duration': 4.48},
#  {'text': 'some of the most incredible artificial',
#   'start': 8.639,
#   'duration': 4.561},
#  {'text': 'intelligence systems in the history of',
#   'start': 11.2,
#   'duration': 4.8},
#  {'text': 'computing including alfred zero that',
#   'start': 13.2,
#   'duration': 3.68},
#  {'text': 'learned', 'start': 16.0, 'duration': 2.96},
#  {'text': 'all by itself to play the game of gold',
#   'start': 16.88,
#   'duration': 4.559},
#  {'text': 'better than any human in the world and',
#   'start': 18.96,
#   'duration': 5.6},
#  {'text': 'alpha fold two that solved protein',
#   'start': 21.439,
#   'duration': 4.241},
#  {'text': 'folding', 'start': 24.56, 'duration': 4.16},
#  {'text': 'both tasks considered nearly impossible',
#   'start': 25.68,
#   'duration': 5.439},
#  {'text': 'for a very long time', 'start': 28.72, 'duration': 4.4},
#  {'text': 'demus is widely considered to be one of',
#   'start': 31.119,
#   'duration': 4.481},
#  {'text': 'the most brilliant and impactful humans',
#   'start': 33.12,
#   'duration': 4.0},
#  {'text': 'in the history of artificial', 'start': 35.6, 'duration': 4.24},
#  {'text': 'intelligence and science and engineering',
#   'start': 37.12,
#   'duration': 4.0},
#  {'text': 'in general', 'start': 39.84, 'duration': 3.92},
#  {'text': 'this was truly an honor and a pleasure',
#   'start': 41.12,
#   'duration': 4.959},
#  {'text': 'for me to finally sit down with him for',
#   'start': 43.76,
#   'duration': 4.799},
#  {'text': "this conversation and i'm sure we will",
#   'start': 46.079,
#   'duration': 5.361},
#  {'text': 'talk many times again in the future',
#   'start': 48.559,
#   'duration': 4.721},
#  {'text': 'this is the lex friedman podcast to',
#   'start': 51.44,
#   'duration': 4.0},
#  {'text': 'support it please check out our sponsors',
#   'start': 53.28,
#   'duration': 4.959},
#  {'text': 'in the description and now dear friends',
#   'start': 55.44,
#   'duration': 4.16},
#  {'text': "here's demis", 'start': 58.239, 'duration': 3.201},
#  {'text': 'hassabis', 'start': 59.6, 'duration': 3.36},
#  {'text': "let's start with a bit of a personal",
#   'start': 61.44,
#   'duration': 2.48},
#  {'text': 'question', 'start': 62.96, 'duration': 3.839},
#  {'text': 'am i an ai program you wrote to', 'start': 63.92, 'duration': 4.8},
#  {'text': 'interview people until i get good enough',
#   'start': 66.799,
#   'duration': 4.161},
#  {'text': 'to interview you', 'start': 68.72, 'duration': 4.24},
#  {'text': "well i'll be impressed if if you were",
#   'start': 70.96,
#   'duration': 3.839},
#  {'text': "i'd be impressed by myself if you were i",
#   'start': 72.96,
#   'duration': 3.44},
#  {'text': "don't think we're quite up to that yet",
#   'start': 74.799,
#   'duration': 3.921},
#  {'text': "but uh maybe you're from the future lex",
#   'start': 76.4,
#   'duration': 4.48},
#  {'text': 'if you did would you tell me is that is',
#   'start': 78.72,
#   'duration': 3.84},
#  {'text': 'that a good thing to tell a language',
#   'start': 80.88,
#   'duration': 4.08},
#  {'text': "model that's tasked with interviewing",
#   'start': 82.56,
#   'duration': 5.199},
#  {'text': "that it is in fact um ai maybe we're in",
#   'start': 84.96,
#   'duration': 5.28},
#  {'text': 'a kind of meta turing test uh probably',
#   'start': 87.759,
#   'duration': 4.081},
#  {'text': 'probably it would be a good idea not to',
#   'start': 90.24,
#   'duration': 2.96},
#  {'text': "tell you so it doesn't change your",
#   'start': 91.84,
#   'duration': 2.88},
#  {'text': 'behavior right this is a kind of', 'start': 93.2, 'duration': 3.2},
#  {'text': 'heisenberg uncertainty principle',
#   'start': 94.72,
#   'duration': 3.359},
#  {'text': 'situation if i told you you behave',
#   'start': 96.4,
#   'duration': 3.12},
#  {'text': "differently yeah maybe that's what's",
#   'start': 98.079,
#   'duration': 3.201},
#  {'text': 'happening with us of course this is a',
#   'start': 99.52,
#   'duration': 4.0},
#  {'text': 'benchmark from the future where they',
#   'start': 101.28,
#   'duration': 6.56},
#  {'text': 'replay 2022 as a year before ais were',
#   'start': 103.52,
#   'duration': 7.36},
#  {'text': 'good enough yet and now we want to see',
#   'start': 107.84,
#   'duration': 5.919},
#  {'text': 'is it going to pass exactly', 'start': 110.88, 'duration': 4.559},
#  {'text': 'if i was such a', 'start': 113.759, 'duration': 3.36},
#  {'text': 'program would you be able to tell do you',
#   'start': 115.439,
#   'duration': 4.481},
#  {'text': 'think so to the touring test question',
#   'start': 117.119,
#   'duration': 5.921},
#  {'text': "you've talked about", 'start': 119.92, 'duration': 3.12},
#  {'text': 'the benchmark for solving intelligence',
#   'start': 123.2,
#   'duration': 3.919},
#  {'text': 'what would be the impressive thing',
#   'start': 125.68,
#   'duration': 2.96},
#  {'text': "you've talked about winning a nobel",
#   'start': 127.119,
#   'duration': 4.161},
#  {'text': 'prize in a system winning a nobel prize',
#   'start': 128.64,
#   'duration': 4.72},
#  {'text': 'but i still return to the touring test',
#   'start': 131.28,
#   'duration': 3.76},
#  {'text': 'as a compelling test the spirit of the',
#   'start': 133.36,
#   'duration': 3.76},
#  {'text': 'touring test is a compelling test',
#   'start': 135.04,
#   'duration': 3.76},
#  {'text': "yeah the turing test of course it's been",
#   'start': 137.12,
#   'duration': 3.52},
#  {'text': "unbelievably influential and turing's",
#   'start': 138.8,
#   'duration': 4.24},
#  {'text': 'one of my all-time heroes but i think if',
#   'start': 140.64,
#   'duration': 4.239},
#  {'text': 'you look back at the 1950 papers',
#   'start': 143.04,
#   'duration': 3.839},
#  {'text': 'original paper and read the original',
#   'start': 144.879,
#   'duration': 4.0},
#  {'text': "you'll see i don't think he meant it to",
#   'start': 146.879,
#   'duration': 4.321},
#  {'text': 'be a rigorous formal test i think it was',
#   'start': 148.879,
#   'duration': 4.161},
#  {'text': 'more like a thought experiment almost a',
#   'start': 151.2,
#   'duration': 3.52},
#  {'text': 'bit of philosophy he was writing if you',
#   'start': 153.04,
#   'duration': 3.52},
#  {'text': 'look at the style of the paper and you',
#   'start': 154.72,
#   'duration': 3.28},
#  {'text': "can see he didn't specify it very",
#   'start': 156.56,
#   'duration': 3.52},
#  {'text': "rigorously so for example he didn't",
#   'start': 158.0,
#   'duration': 4.879},
#  {'text': 'specify the knowledge that the expert or',
#   'start': 160.08,
#   'duration': 5.439},
#  {'text': 'judge would have um not you know how',
#   'start': 162.879,
#   'duration': 4.801},
#  {'text': 'much time would they have to investigate',
#   'start': 165.519,
#   'duration': 4.0},
#  {'text': 'this so these important parameters if',
#   'start': 167.68,
#   'duration': 4.48},
#  {'text': 'you were gonna make it uh a true sort of',
#   'start': 169.519,
#   'duration': 3.921},
#  {'text': 'formal test', 'start': 172.16, 'duration': 4.32},
#  {'text': 'um and you know some by some measures',
#   'start': 173.44,
#   'duration': 4.879},
#  {'text': 'people claimed the turing test passed',
#   'start': 176.48,
#   'duration': 3.36},
#  {'text': 'several you know a decade ago i remember',
#   'start': 178.319,
#   'duration': 3.2},
#  {'text': 'someone claiming that with a with a kind',
#   'start': 179.84,
#   'duration': 4.56},
#  {'text': 'of very bog standard normal uh',
#   'start': 181.519,
#   'duration': 5.44},
#  {'text': 'logic model um because they pretended it',
#   'start': 184.4,
#   'duration': 5.199},
#  {'text': 'was a it was a kid so the the judges',
#   'start': 186.959,
#   'duration': 4.721},
#  {'text': 'thought that the machine you know was',
#   'start': 189.599,
#   'duration': 5.121},
#  {'text': 'was a was a child so um that would be',
#   'start': 191.68,
#   'duration': 5.52},
#  {'text': 'very different from an expert ai person',
#   'start': 194.72,
#   'duration': 4.32},
#  {'text': 'uh interrogating a machine and knowing',
#   'start': 197.2,
#   'duration': 5.119},
#  {'text': 'how it was built and so on so i think um',
#   'start': 199.04,
#   'duration': 4.64},
#  {'text': 'you know we should probably move away',
#   'start': 202.319,
#   'duration': 4.081},
#  {'text': 'from that as a formal test and move more',
#   'start': 203.68,
#   'duration': 5.839},
#  {'text': 'towards a general test where we test the',
#   'start': 206.4,
#   'duration': 5.759},
#  {'text': 'ai capabilities on a range of tasks and',
#   'start': 209.519,
#   'duration': 5.121},
#  {'text': 'see if it reaches human level or above',
#   'start': 212.159,
#   'duration': 5.121},
#  {'text': 'performance on maybe thousands perhaps',
#   'start': 214.64,
#   'duration': 4.64},
#  {'text': 'even millions of tasks eventually and',
#   'start': 217.28,
#   'duration': 4.56},
#  {'text': 'cover the entire sort of cognitive space',
#   'start': 219.28,
#   'duration': 4.08},
#  {'text': 'so i think', 'start': 221.84, 'duration': 3.119},
#  {'text': 'for its time it was an amazing thought',
#   'start': 223.36,
#   'duration': 3.92},
#  {'text': 'experiment and also 1950s obviously it',
#   'start': 224.959,
#   'duration': 4.321},
#  {'text': 'was barely the dawn of the computer age',
#   'start': 227.28,
#   'duration': 4.08},
#  {'text': 'so of course he only thought about text',
#   'start': 229.28,
#   'duration': 4.239},
#  {'text': 'and now um we have a lot more different',
#   'start': 231.36,
#   'duration': 3.12},
#  {'text': 'inputs', 'start': 233.519, 'duration': 3.44},
#  {'text': 'so yeah maybe the better thing to test',
#   'start': 234.48,
#   'duration': 4.319},
#  {'text': 'is the generalizability so across',
#   'start': 236.959,
#   'duration': 4.0},
#  {'text': "multiple tasks but i think it's also",
#   'start': 238.799,
#   'duration': 5.761},
#  {'text': 'possible as as systems like god show',
#   'start': 240.959,
#   'duration': 4.56},
#  {'text': 'that', 'start': 244.56, 'duration': 2.879},
#  {'text': 'eventually that might map right back to',
#   'start': 245.519,
#   'duration': 3.681},
#  {'text': 'language so you might be able to',
#   'start': 247.439,
#   'duration': 4.08},
#  {'text': 'demonstrate your ability to generalize',
#   'start': 249.2,
#   'duration': 3.92},
#  {'text': 'across tasks', 'start': 251.519, 'duration': 3.841},
#  {'text': 'by then communicating your ability to',
#   'start': 253.12,
#   'duration': 4.399},
#  {'text': 'generalize across tasks which is kind of',
#   'start': 255.36,
#   'duration': 3.68},
#  {'text': 'what we do through conversation anyway',
#   'start': 257.519,
#   'duration': 3.201},
#  {'text': 'when we jump around', 'start': 259.04, 'duration': 3.52},
#  {'text': "ultimately what's in there in that",
#   'start': 260.72,
#   'duration': 4.24},
#  {'text': 'conversation is not just you moving',
#   'start': 262.56,
#   'duration': 4.32},
#  {'text': 'around knowledge', 'start': 264.96, 'duration': 4.16},
#  {'text': "it's you moving around like these",
#   'start': 266.88,
#   'duration': 4.879},
#  {'text': 'entirely different modalities of',
#   'start': 269.12,
#   'duration': 5.84},
#  {'text': 'understanding that ultimately map to',
#   'start': 271.759,
#   'duration': 5.121},
#  {'text': 'your ability to', 'start': 274.96, 'duration': 4.48},
#  {'text': 'to uh operate successfully in all these',
#   'start': 276.88,
#   'duration': 5.599},
#  {'text': 'domains which you can think of as tasks',
#   'start': 279.44,
#   'duration': 5.52},
#  {'text': 'yeah i think certainly we as humans use',
#   'start': 282.479,
#   'duration': 4.961},
#  {'text': 'language as our main generalization',
#   'start': 284.96,
#   'duration': 5.04},
#  {'text': 'communication tool so i think we end up',
#   'start': 287.44,
#   'duration': 4.88},
#  {'text': 'thinking in language and expressing our',
#   'start': 290.0,
#   'duration': 4.96},
#  {'text': "solutions in language um so it's going",
#   'start': 292.32,
#   'duration': 4.08},
#  {'text': 'to be very powerful', 'start': 294.96, 'duration': 5.12},
#  {'text': 'uh uh mode in which to uh explain you',
#   'start': 296.4,
#   'duration': 5.2},
#  {'text': "know the system to explain what it's",
#   'start': 300.08,
#   'duration': 4.8},
#  {'text': "doing um but i don't think it's the only",
#   'start': 301.6,
#   'duration': 6.56},
#  {'text': 'uh uh modality that matters so i think',
#   'start': 304.88,
#   'duration': 4.72},
#  {'text': "there's gonna be a lot of you know",
#   'start': 308.16,
#   'duration': 2.72},
#  {'text': "there's there's a lot of different ways",
#   'start': 309.6,
#   'duration': 4.24},
#  {'text': 'to express uh capabilities uh other than',
#   'start': 310.88,
#   'duration': 4.56},
#  {'text': 'just language', 'start': 313.84, 'duration': 2.88},
#  {'text': 'yeah visual', 'start': 315.44, 'duration': 4.479},
#  {'text': 'robotics body language', 'start': 316.72, 'duration': 4.319},
#  {'text': 'um', 'start': 319.919, 'duration': 3.041},
#  {'text': 'yeah action is the interactive aspect of',
#   'start': 321.039,
#   'duration': 3.761},
#  {'text': "all that that's all part of it but",
#   'start': 322.96,
#   'duration': 3.28},
#  {'text': "what's interesting with gato is that",
#   'start': 324.8,
#   'duration': 4.08},
#  {'text': "it's a it's it's it's sort of pushing",
#   'start': 326.24,
#   'duration': 4.48},
#  {'text': 'prediction to the maximum in terms of',
#   'start': 328.88,
#   'duration': 3.84},
#  {'text': 'like you know mapping arbitrary',
#   'start': 330.72,
#   'duration': 4.08},
#  {'text': 'sequences to other sequences and sort of',
#   'start': 332.72,
#   'duration': 3.36},
#  {'text': "just predicting what's going to happen",
#   'start': 334.8,
#   'duration': 3.839},
#  {'text': 'next so prediction seems to be', 'start': 336.08, 'duration': 4.88},
#  {'text': 'fundamental to intelligence', 'start': 338.639, 'duration': 4.161},
#  {'text': "and what you're predicting", 'start': 340.96, 'duration': 4.0},
#  {'text': "doesn't so much matter yeah it seems",
#   'start': 342.8,
#   'duration': 3.839},
#  {'text': 'like you can generalize that quite well',
#   'start': 344.96,
#   'duration': 3.28},
#  {'text': 'so obviously language models predict the',
#   'start': 346.639,
#   'duration': 4.241},
#  {'text': 'next word um gato predicts potentially',
#   'start': 348.24,
#   'duration': 6.0},
#  {'text': "any uh action or any token uh and it's",
#   'start': 350.88,
#   'duration': 4.72},
#  {'text': "just the beginning really it's our most",
#   'start': 354.24,
#   'duration': 3.76},
#  {'text': 'general agent one could call it so far',
#   'start': 355.6,
#   'duration': 4.4},
#  {'text': 'but um you know that itself can be',
#   'start': 358.0,
#   'duration': 3.6},
#  {'text': "scaled up massively more than we've done",
#   'start': 360.0,
#   'duration': 3.039},
#  {'text': "so far obviously we're in the in the",
#   'start': 361.6,
#   'duration': 4.08},
#  {'text': 'middle of doing that but the big part of',
#   'start': 363.039,
#   'duration': 6.081},
#  {'text': 'solving agi is creating benchmarks that',
#   'start': 365.68,
#   'duration': 6.48},
#  {'text': 'help us get closer and closer sort of',
#   'start': 369.12,
#   'duration': 4.799},
#  {'text': 'creating benchmarks that test the',
#   'start': 372.16,
#   'duration': 3.599},
#  {'text': "journalizability and it's just still",
#   'start': 373.919,
#   'duration': 4.881},
#  {'text': 'interesting that this fella alan turing',
#   'start': 375.759,
#   'duration': 5.601},
#  {'text': 'was one of the first and probably still',
#   'start': 378.8,
#   'duration': 4.959},
#  {'text': 'one of the only people that was trying',
#   'start': 381.36,
#   'duration': 4.24},
#  {'text': 'maybe philosophically but was trying to',
#   'start': 383.759,
#   'duration': 3.44},
#  {'text': 'formulate a benchmark that could be',
#   'start': 385.6,
#   'duration': 3.2},
#  {'text': 'followed it is', 'start': 387.199, 'duration': 4.081},
#  {'text': "even though it's it's fuzzy it's still",
#   'start': 388.8,
#   'duration': 4.08},
#  {'text': 'sufficiently rigorous to where you can',
#   'start': 391.28,
#   'duration': 3.84},
#  {'text': 'run that test and i still think',
#   'start': 392.88,
#   'duration': 4.159},
#  {'text': 'something like the touring test will at',
#   'start': 395.12,
#   'duration': 3.519},
#  {'text': 'the end of the day', 'start': 397.039, 'duration': 3.361},
#  {'text': 'be the thing that truly', 'start': 398.639, 'duration': 3.84},
#  {'text': 'impresses other humans', 'start': 400.4, 'duration': 4.239},
#  {'text': 'so that you can have a close friend',
#   'start': 402.479,
#   'duration': 3.921},
#  {'text': "who's an ai system", 'start': 404.639, 'duration': 3.601},
#  {'text': 'for that friend to be a good friend',
#   'start': 406.4,
#   'duration': 4.0},
#  {'text': "they're going to have to be able to",
#   'start': 408.24,
#   'duration': 4.799},
#  {'text': 'uh play starcraft', 'start': 410.4, 'duration': 4.239},
#  {'text': "and they're going to have to do all of",
#   'start': 413.039,
#   'duration': 5.041},
#  {'text': 'these tasks um get you a beer so the',
#   'start': 414.639,
#   'duration': 5.28},
#  {'text': 'robotics tasks', 'start': 418.08, 'duration': 5.04},
#  {'text': 'uh play games with you use language',
#   'start': 419.919,
#   'duration': 5.84},
#  {'text': 'humor all those kinds of things but that',
#   'start': 423.12,
#   'duration': 4.799},
#  {'text': 'ultimately can boil down to language it',
#   'start': 425.759,
#   'duration': 4.401},
#  {'text': 'feels like not in terms of the ai',
#   'start': 427.919,
#   'duration': 4.56},
#  {'text': 'community but in terms of the actual',
#   'start': 430.16,
#   'duration': 4.159},
#  {'text': 'impact of general intelligence on the',
#   'start': 432.479,
#   'duration': 3.681},
#  {'text': 'world it feels like language will be the',
#   'start': 434.319,
#   'duration': 4.641},
#  {'text': 'place where it truly shines i think so',
#   'start': 436.16,
#   'duration': 4.72},
#  {'text': "because it's such an important kind of",
#   'start': 438.96,
#   'duration': 4.079},
#  {'text': "input output for us i think you're right",
#   'start': 440.88,
#   'duration': 4.0},
#  {'text': 'i think the turing test that what the',
#   'start': 443.039,
#   'duration': 4.241},
#  {'text': 'the kind of the the philosophy behind it',
#   'start': 444.88,
#   'duration': 5.36},
#  {'text': 'which is the idea of can can a machine',
#   'start': 447.28,
#   'duration': 7.6},
#  {'text': 'mimic the behaviors of a human and men',
#   'start': 450.24,
#   'duration': 6.799},
#  {'text': 'and i would say wider than just language',
#   'start': 454.88,
#   'duration': 3.759},
#  {'text': 'and text', 'start': 457.039, 'duration': 3.521},
#  {'text': 'then you know in terms of actions and',
#   'start': 458.639,
#   'duration': 3.601},
#  {'text': 'everything else creativity all these',
#   'start': 460.56,
#   'duration': 4.079},
#  {'text': 'things then um if it can sort of match',
#   'start': 462.24,
#   'duration': 5.04},
#  {'text': 'or exceed human cognitive capabilities',
#   'start': 464.639,
#   'duration': 4.481},
#  {'text': 'then i think we have a you know true',
#   'start': 467.28,
#   'duration': 3.44},
#  {'text': 'intelligence so i thought from that',
#   'start': 469.12,
#   'duration': 3.359},
#  {'text': "perspective you're right i think he did",
#   'start': 470.72,
#   'duration': 5.12},
#  {'text': 'formulate the right uh kind of uh setup',
#   'start': 472.479,
#   'duration': 5.361},
#  {'text': "i just i think there'll be a kind of",
#   'start': 475.84,
#   'duration': 3.359},
#  {'text': 'humor', 'start': 477.84, 'duration': 3.28},
#  {'text': 'in the ai systems of the future looking',
#   'start': 479.199,
#   'duration': 4.241},
#  {'text': 'back to this conversation', 'start': 481.12, 'duration': 4.88},
#  {'text': 'and thinking about the touring test',
#   'start': 483.44,
#   'duration': 5.12},
#  {'text': 'and uh also thinking about', 'start': 486.0, 'duration': 4.319},
#  {'text': 'by that time they would know which year',
#   'start': 488.56,
#   'duration': 4.639},
#  {'text': 'they were finally able to sort of cross',
#   'start': 490.319,
#   'duration': 4.241},
#  {'text': 'the threshold of human level', 'start': 493.199, 'duration': 3.921},
#  {'text': 'intelligence and think', 'start': 494.56, 'duration': 4.319},
#  {'text': 'how funny it is that we humans were',
#   'start': 497.12,
#   'duration': 2.72},
#  {'text': 'still', 'start': 498.879, 'duration': 3.44},
#  {'text': 'confused about this whole problem',
#   'start': 499.84,
#   'duration': 4.72},
#  {'text': 'that has been long ago been solved',
#   'start': 502.319,
#   'duration': 4.0},
#  {'text': 'well hello to the ai agents of the',
#   'start': 504.56,
#   'duration': 4.8},
#  {'text': 'future anyway so going back to your',
#   'start': 506.319,
#   'duration': 4.961},
#  {'text': 'to your journey when did you fall in',
#   'start': 509.36,
#   'duration': 4.239},
#  {'text': 'love with programming first', 'start': 511.28, 'duration': 4.16},
#  {'text': "well it's pretty uh pretty young age",
#   'start': 513.599,
#   'duration': 3.761},
#  {'text': 'actually so um', 'start': 515.44, 'duration': 4.399},
#  {'text': 'you know i started off uh actually games',
#   'start': 517.36,
#   'duration': 4.479},
#  {'text': 'was my first love so starting to play',
#   'start': 519.839,
#   'duration': 3.76},
#  {'text': 'chess when i was around four years old',
#   'start': 521.839,
#   'duration': 3.761},
#  {'text': 'and then um it was actually with',
#   'start': 523.599,
#   'duration': 4.321},
#  {'text': 'winnings from a chess competition that i',
#   'start': 525.6,
#   'duration': 4.0},
#  {'text': 'managed to buy my first chess computer',
#   'start': 527.92,
#   'duration': 2.88},
#  {'text': 'when i was about eight years old it was',
#   'start': 529.6,
#   'duration': 3.44},
#  {'text': 'a zx spectrum which was hugely popular',
#   'start': 530.8,
#   'duration': 3.84},
#  {'text': 'in the uk at the time', 'start': 533.04, 'duration': 4.32},
#  {'text': "and uh it's amazing machine because i",
#   'start': 534.64,
#   'duration': 4.639},
#  {'text': 'think it trained a whole generation of',
#   'start': 537.36,
#   'duration': 4.08},
#  {'text': 'programmers in the uk because it was so',
#   'start': 539.279,
#   'duration': 3.761},
#  {'text': 'accessible you know you literally',
#   'start': 541.44,
#   'duration': 3.12},
#  {'text': 'switched it on and there was the basic',
#   'start': 543.04,
#   'duration': 4.0},
#  {'text': 'prompt and you could just get going and',
#   'start': 544.56,
#   'duration': 4.24},
#  {'text': "um my parents didn't really know",
#   'start': 547.04,
#   'duration': 3.6},
#  {'text': 'anything about computers so but because',
#   'start': 548.8,
#   'duration': 3.68},
#  {'text': 'it was my money from a chess competition',
#   'start': 550.64,
#   'duration': 4.48},
#  {'text': 'i could i could say i i wanted to buy it',
#   'start': 552.48,
#   'duration': 4.479},
#  {'text': 'uh and then you know i just went to',
#   'start': 555.12,
#   'duration': 5.04},
#  {'text': 'bookstores got books on programming and',
#   'start': 556.959,
#   'duration': 5.601},
#  {'text': 'um started typing in you know the',
#   'start': 560.16,
#   'duration': 4.72},
#  {'text': 'programming code and and then of course',
#   'start': 562.56,
#   'duration': 4.08},
#  {'text': 'um once you start doing that you start',
#   'start': 564.88,
#   'duration': 3.28},
#  {'text': 'adjusting it and then making your own',
#   'start': 566.64,
#   'duration': 3.44},
#  {'text': "games and that's when i fell in love",
#   'start': 568.16,
#   'duration': 3.359},
#  {'text': 'with computers and realized that they',
#   'start': 570.08,
#   'duration': 5.12},
#  {'text': 'were a very magical device um in a way i',
#   'start': 571.519,
#   'duration': 4.88},
#  {'text': 'kind of i would have been able to',
#   'start': 575.2,
#   'duration': 2.72},
#  {'text': 'explain this at the time but i felt that',
#   'start': 576.399,
#   'duration': 3.041},
#  {'text': 'they were sort of almost a magical',
#   'start': 577.92,
#   'duration': 3.76},
#  {'text': 'extension of your mind i always had this',
#   'start': 579.44,
#   'duration': 3.76},
#  {'text': "feeling and i've always loved this about",
#   'start': 581.68,
#   'duration': 3.36},
#  {'text': 'computers that you can set them off',
#   'start': 583.2,
#   'duration': 4.24},
#  {'text': 'doing something some task for you you',
#   'start': 585.04,
#   'duration': 4.32},
#  {'text': 'can go to sleep come back the next day',
#   'start': 587.44,
#   'duration': 2.959},
#  {'text': "and it's solved", 'start': 589.36, 'duration': 3.84},
#  {'text': 'um you know that feels magical to me so',
#   'start': 590.399,
#   'duration': 4.401},
#  {'text': 'i mean all machines do that to some',
#   'start': 593.2,
#   'duration': 3.68},
#  {'text': 'extent they all enhance our natural',
#   'start': 594.8,
#   'duration': 3.84},
#  {'text': 'capabilities obviously cars make us',
#   'start': 596.88,
#   'duration': 4.16},
#  {'text': 'allow us to move faster than we can run',
#   'start': 598.64,
#   'duration': 4.879},
#  {'text': 'but this was a machine to extend the',
#   'start': 601.04,
#   'duration': 3.359},
#  {'text': 'mind', 'start': 603.519, 'duration': 3.601},
#  {'text': 'and and then of course ai is the',
#   'start': 604.399,
#   'duration': 4.88},
#  {'text': 'ultimate expression of what a machine',
#   'start': 607.12,
#   'duration': 4.959},
#  {'text': 'may be able to do or learn so',
#   'start': 609.279,
#   'duration': 4.641},
#  {'text': 'very naturally for me that thought',
#   'start': 612.079,
#   'duration': 3.841},
#  {'text': 'extended into into ai quite quickly',
#   'start': 613.92,
#   'duration': 4.479},
#  {'text': 'remember the the programming language',
#   'start': 615.92,
#   'duration': 3.84},
#  {'text': 'that was first', 'start': 618.399, 'duration': 2.641},
#  {'text': 'started', 'start': 619.76, 'duration': 2.72},
#  {'text': 'special to the machine no it was just',
#   'start': 621.04,
#   'duration': 2.96},
#  {'text': 'the base it was just i think it was just',
#   'start': 622.48,
#   'duration': 3.599},
#  {'text': "basic uh on the zx spectrum i don't know",
#   'start': 624.0,
#   'duration': 3.92},
#  {'text': 'what specific form it was and then later',
#   'start': 626.079,
#   'duration': 5.041},
#  {'text': 'on i got a commodore amiga which uh',
#   'start': 627.92,
#   'duration': 5.2},
#  {'text': "was a fantastic machine no you're just",
#   'start': 631.12,
#   'duration': 3.92},
#  {'text': 'showing off so yeah well lots of my',
#   'start': 633.12,
#   'duration': 4.0},
#  {'text': "friends had atari st's and i i managed",
#   'start': 635.04,
#   'duration': 3.76},
#  {'text': 'to get amigas it was a bit more powerful',
#   'start': 637.12,
#   'duration': 3.839},
#  {'text': 'and uh and that was incredible and used',
#   'start': 638.8,
#   'duration': 5.2},
#  {'text': 'to do um programming in assembler and',
#   'start': 640.959,
#   'duration': 5.921},
#  {'text': 'and uh also amos basic this this',
#   'start': 644.0,
#   'duration': 4.64},
#  {'text': 'specific form of basic it was incredible',
#   'start': 646.88,
#   'duration': 4.0},
#  {'text': 'actually as well all my coding skills',
#   'start': 648.64,
#   'duration': 4.48},
#  {'text': 'and when did you fall in love with ai so',
#   'start': 650.88,
#   'duration': 4.56},
#  {'text': 'when did you first', 'start': 653.12, 'duration': 3.92},
#  {'text': 'start to gain an understanding that you',
#   'start': 655.44,
#   'duration': 4.079},
#  {'text': 'can not just write programs that',
#   'start': 657.04,
#   'duration': 4.479},
#  {'text': 'do some mathematical operations for you',
#   'start': 659.519,
#   'duration': 4.961},
#  {'text': "while you sleep but something that's",
#   'start': 661.519,
#   'duration': 4.88},
#  {'text': 'a keen to', 'start': 664.48, 'duration': 4.24},
#  {'text': 'bringing an entity to life', 'start': 666.399, 'duration': 3.201},
#  {'text': 'sort of', 'start': 668.72, 'duration': 3.04},
#  {'text': 'a thing that can figure out something',
#   'start': 669.6,
#   'duration': 4.16},
#  {'text': 'more complicated than uh', 'start': 671.76, 'duration': 4.0},
#  {'text': 'than a simple mathematical operation',
#   'start': 673.76,
#   'duration': 3.759},
#  {'text': 'yeah so there was a few stages for me',
#   'start': 675.76,
#   'duration': 4.16},
#  {'text': 'all while i was very young so first of',
#   'start': 677.519,
#   'duration': 4.241},
#  {'text': 'all as i was trying to improve at',
#   'start': 679.92,
#   'duration': 3.44},
#  {'text': 'playing chess i was captaining various',
#   'start': 681.76,
#   'duration': 3.199},
#  {'text': 'england junior chess teams and at the',
#   'start': 683.36,
#   'duration': 3.28},
#  {'text': 'time when i was about you know maybe 10',
#   'start': 684.959,
#   'duration': 3.44},
#  {'text': '11 years old i was gonna become a',
#   'start': 686.64,
#   'duration': 3.12},
#  {'text': 'professional chess player that was my',
#   'start': 688.399,
#   'duration': 2.241},
#  {'text': 'first', 'start': 689.76, 'duration': 4.319},
#  {'text': 'thought um that dream was there sure she',
#   'start': 690.64,
#   'duration': 5.04},
#  {'text': 'tried to get to the highest level yeah',
#   'start': 694.079,
#   'duration': 4.241},
#  {'text': 'so i was um you know i got to when i was',
#   'start': 695.68,
#   'duration': 4.32},
#  {'text': 'about 12 years old i got to master stand',
#   'start': 698.32,
#   'duration': 3.199},
#  {'text': 'and i was second highest rated player in',
#   'start': 700.0,
#   'duration': 3.279},
#  {'text': 'the world to judith polgar who obviously',
#   'start': 701.519,
#   'duration': 4.161},
#  {'text': 'ended up being an amazing chess player',
#   'start': 703.279,
#   'duration': 6.161},
#  {'text': "and uh world women's champion and when i",
#   'start': 705.68,
#   'duration': 5.2},
#  {'text': 'was trying to improve at chess where you',
#   'start': 709.44,
#   'duration': 2.959},
#  {'text': 'know what you do is you obviously first',
#   'start': 710.88,
#   'duration': 2.88},
#  {'text': "of all you're trying to improve your own",
#   'start': 712.399,
#   'duration': 4.56},
#  {'text': 'thinking processes so that leads you to',
#   'start': 713.76,
#   'duration': 4.72},
#  {'text': 'thinking about thinking how is your',
#   'start': 716.959,
#   'duration': 3.601},
#  {'text': 'brain coming up with these ideas why is',
#   'start': 718.48,
#   'duration': 4.479},
#  {'text': 'it making mistakes how can you how can',
#   'start': 720.56,
#   'duration': 4.16},
#  {'text': 'you improve that thought process but the',
#   'start': 722.959,
#   'duration': 3.921},
#  {'text': 'second thing is that you it was just the',
#   'start': 724.72,
#   'duration': 4.239},
#  {'text': 'beginning this was like in the in the',
#   'start': 726.88,
#   'duration': 4.399},
#  {'text': 'early 80s mid 80s of chess computers if',
#   'start': 728.959,
#   'duration': 3.68},
#  {'text': 'you remember they were physical boards',
#   'start': 731.279,
#   'duration': 2.881},
#  {'text': 'like the one we have in front of us and',
#   'start': 732.639,
#   'duration': 3.361},
#  {'text': 'you pressed down the you know the',
#   'start': 734.16,
#   'duration': 4.16},
#  {'text': 'squares and i think kasparov had a',
#   'start': 736.0,
#   'duration': 5.279},
#  {'text': 'branded version of it that i i i got and',
#   'start': 738.32,
#   'duration': 5.04},
#  {'text': "um you were you know used to they're not",
#   'start': 741.279,
#   'duration': 3.521},
#  {'text': 'as strong as they are today but they',
#   'start': 743.36,
#   'duration': 3.2},
#  {'text': 'were they were pretty strong and you',
#   'start': 744.8,
#   'duration': 4.4},
#  {'text': 'used to practice against them um to try',
#   'start': 746.56,
#   'duration': 4.24},
#  {'text': 'and improve your openings and other',
#   'start': 749.2,
#   'duration': 3.199},
#  {'text': 'things and so i remember i think i',
#   'start': 750.8,
#   'duration': 2.88},
#  {'text': 'probably got my first one i was around',
#   'start': 752.399,
#   'duration': 4.161},
#  {'text': '11 or 12. and i remember thinking um',
#   'start': 753.68,
#   'duration': 4.32},
#  {'text': 'this is amazing you know how how has',
#   'start': 756.56,
#   'duration': 4.32},
#  {'text': 'someone programmed uh uh this this chess',
#   'start': 758.0,
#   'duration': 5.76},
#  {'text': 'board to play chess uh and uh it was',
#   'start': 760.88,
#   'duration': 4.959},
#  {'text': 'very formative book i bought which was',
#   'start': 763.76,
#   'duration': 4.079},
#  {'text': 'called the chess computer handbook by',
#   'start': 765.839,
#   'duration': 4.481},
#  {'text': 'david levy which came out in 1984 or',
#   'start': 767.839,
#   'duration': 3.521},
#  {'text': 'something so i must have got it when i',
#   'start': 770.32,
#   'duration': 3.84},
#  {'text': 'was about 11 12 and it explained fully',
#   'start': 771.36,
#   'duration': 4.8},
#  {'text': 'how these chess programs were made i',
#   'start': 774.16,
#   'duration': 4.72},
#  {'text': 'remember my first ai program being uh',
#   'start': 776.16,
#   'duration': 5.119},
#  {'text': "programming my amiga it couldn't it",
#   'start': 778.88,
#   'duration': 4.0},
#  {'text': "wasn't powerful enough to play chess i",
#   'start': 781.279,
#   'duration': 2.961},
#  {'text': "couldn't write a whole chess program but",
#   'start': 782.88,
#   'duration': 3.84},
#  {'text': 'i wrote a program for it to play othello',
#   'start': 784.24,
#   'duration': 4.0},
#  {'text': "reversey it's sometimes called i think",
#   'start': 786.72,
#   'duration': 3.919},
#  {'text': 'in the u.s and so a slightly simpler',
#   'start': 788.24,
#   'duration': 4.32},
#  {'text': 'game than chess but i used all of the',
#   'start': 790.639,
#   'duration': 3.841},
#  {'text': 'principles that chess programs had alpha',
#   'start': 792.56,
#   'duration': 3.92},
#  {'text': 'beta search all of that and that was my',
#   'start': 794.48,
#   'duration': 3.28},
#  {'text': 'first ai program i remember that very',
#   'start': 796.48,
#   'duration': 3.2},
#  {'text': 'well was around 12 years old so that',
#   'start': 797.76,
#   'duration': 4.079},
#  {'text': 'that that brought me into ai and then',
#   'start': 799.68,
#   'duration': 4.56},
#  {'text': 'the second part was later on uh when i',
#   'start': 801.839,
#   'duration': 4.721},
#  {'text': 'was around 1617 and i was writing games',
#   'start': 804.24,
#   'duration': 4.48},
#  {'text': 'professionally designing games uh',
#   'start': 806.56,
#   'duration': 4.32},
#  {'text': 'writing a game called theme park which',
#   'start': 808.72,
#   'duration': 5.2},
#  {'text': 'um had ai as a core gameplay component',
#   'start': 810.88,
#   'duration': 5.92},
#  {'text': 'as part of the simulation um and it sold',
#   'start': 813.92,
#   'duration': 4.159},
#  {'text': 'you know millions of copies around the',
#   'start': 816.8,
#   'duration': 3.44},
#  {'text': 'world and people loved the way that the',
#   'start': 818.079,
#   'duration': 4.081},
#  {'text': 'ai even though it was relatively simple',
#   'start': 820.24,
#   'duration': 4.8},
#  {'text': "by today's ai standards um was was",
#   'start': 822.16,
#   'duration': 4.479},
#  {'text': 'reacting to the way you as the player',
#   'start': 825.04,
#   'duration': 3.76},
#  {'text': 'played it so it was called a sandbox',
#   'start': 826.639,
#   'duration': 3.921},
#  {'text': "game so it's one of the first types of",
#   'start': 828.8,
#   'duration': 4.159},
#  {'text': 'games like that along with simcity and',
#   'start': 830.56,
#   'duration': 4.0},
#  {'text': 'it meant that every game you played was',
#   'start': 832.959,
#   'duration': 2.641},
#  {'text': 'unique', 'start': 834.56, 'duration': 2.8},
#  {'text': 'is there something you could say just on',
#   'start': 835.6,
#   'duration': 3.2},
#  {'text': 'a small tangent', 'start': 837.36, 'duration': 2.4},
#  {'text': 'about', 'start': 838.8, 'duration': 5.36},
#  {'text': 'really impressive ai from a game design',
#   'start': 839.76,
#   'duration': 6.8},
#  {'text': 'human enjoyment perspective', 'start': 844.16, 'duration': 4.72},
#  {'text': "really impressive ai that you've seen in",
#   'start': 846.56,
#   'duration': 4.48},
#  {'text': 'games and maybe what does it take to',
#   'start': 848.88,
#   'duration': 4.319},
#  {'text': 'create ai system and how hard of a',
#   'start': 851.04,
#   'duration': 5.039},
#  {'text': 'problem is that so a million questions',
#   'start': 853.199,
#   'duration': 5.041},
#  {'text': 'just as a brief tangent', 'start': 856.079, 'duration': 4.161},
#  {'text': 'well look i think um', 'start': 858.24, 'duration': 4.32},
#  {'text': 'games uh games have been significant in',
#   'start': 860.24,
#   'duration': 3.92},
#  {'text': 'my life for three reasons so first of',
#   'start': 862.56,
#   'duration': 3.519},
#  {'text': 'all to to i was playing them and',
#   'start': 864.16,
#   'duration': 3.919},
#  {'text': 'training myself on games when i was a',
#   'start': 866.079,
#   'duration': 4.241},
#  {'text': 'kid then i went through a phase of',
#   'start': 868.079,
#   'duration': 4.88},
#  {'text': 'designing games and writing ai4 games so',
#   'start': 870.32,
#   'duration': 4.959},
#  {'text': 'all the games i i professionally wrote',
#   'start': 872.959,
#   'duration': 4.801},
#  {'text': 'uh had ai as a core component and that',
#   'start': 875.279,
#   'duration': 5.521},
#  {'text': 'was mostly in the in the 90s and the',
#   'start': 877.76,
#   'duration': 4.639},
#  {'text': 'reason i was doing that in games',
#   'start': 880.8,
#   'duration': 3.599},
#  {'text': 'industry was at the time the games',
#   'start': 882.399,
#   'duration': 3.761},
#  {'text': 'industry i think was the cutting edge of',
#   'start': 884.399,
#   'duration': 4.0},
#  {'text': 'technology so whether it was graphics',
#   'start': 886.16,
#   'duration': 4.16},
#  {'text': 'with people like john carmack and quake',
#   'start': 888.399,
#   'duration': 5.281},
#  {'text': 'and those kind of things or ai i think',
#   'start': 890.32,
#   'duration': 5.04},
#  {'text': 'actually all the action was going on in',
#   'start': 893.68,
#   'duration': 3.599},
#  {'text': "games and and we've seen we're still",
#   'start': 895.36,
#   'duration': 3.36},
#  {'text': 'reaping the benefits of that even with',
#   'start': 897.279,
#   'duration': 3.68},
#  {'text': 'things like gpus which you know i find',
#   'start': 898.72,
#   'duration': 3.6},
#  {'text': 'ironic was obviously invented for',
#   'start': 900.959,
#   'duration': 2.961},
#  {'text': 'graphics computer graphics but then',
#   'start': 902.32,
#   'duration': 3.759},
#  {'text': 'turns out to be amazingly useful for ai',
#   'start': 903.92,
#   'duration': 3.68},
#  {'text': "it just turns out everything's a matrix",
#   'start': 906.079,
#   'duration': 3.76},
#  {'text': 'multiplication it appears you know in',
#   'start': 907.6,
#   'duration': 3.44},
#  {'text': 'the whole world', 'start': 909.839, 'duration': 4.24},
#  {'text': 'so um so i think games at the time had',
#   'start': 911.04,
#   'duration': 5.12},
#  {'text': 'the most cutting edge ai and a lot of',
#   'start': 914.079,
#   'duration': 4.721},
#  {'text': 'the the games uh uh we you know i was',
#   'start': 916.16,
#   'duration': 4.08},
#  {'text': 'involved in writing so there was a game',
#   'start': 918.8,
#   'duration': 2.8},
#  {'text': 'called black and white which was one',
#   'start': 920.24,
#   'duration': 2.8},
#  {'text': 'game i was involved with in the early',
#   'start': 921.6,
#   'duration': 3.919},
#  {'text': 'stages of which i still think is the',
#   'start': 923.04,
#   'duration': 3.76},
#  {'text': 'most um', 'start': 925.519, 'duration': 3.44},
#  {'text': 'impressive uh example of reinforcement',
#   'start': 926.8,
#   'duration': 4.24},
#  {'text': 'learning in a computer game so in that',
#   'start': 928.959,
#   'duration': 3.921},
#  {'text': 'game you know you trained a little pet',
#   'start': 931.04,
#   'duration': 4.159},
#  {'text': 'animal uh and', 'start': 932.88, 'duration': 4.0},
#  {'text': 'yeah and it sort of learned from how you',
#   'start': 935.199,
#   'duration': 3.2},
#  {'text': 'were treating it so if you treated it',
#   'start': 936.88,
#   'duration': 4.0},
#  {'text': 'badly then it became mean yeah and then',
#   'start': 938.399,
#   'duration': 4.401},
#  {'text': 'it would be mean to to your villagers',
#   'start': 940.88,
#   'duration': 3.6},
#  {'text': 'and your and your population the sort of',
#   'start': 942.8,
#   'duration': 3.2},
#  {'text': 'uh the little tribe that you were',
#   'start': 944.48,
#   'duration': 3.52},
#  {'text': 'running uh but if you were kind to it',
#   'start': 946.0,
#   'duration': 3.68},
#  {'text': 'then it would be kind and people were',
#   'start': 948.0,
#   'duration': 3.759},
#  {'text': 'fascinated by how that was and so was i',
#   'start': 949.68,
#   'duration': 3.519},
#  {'text': 'to be honest with the way it kind of',
#   'start': 951.759,
#   'duration': 4.08},
#  {'text': 'developed and um especially the mapping',
#   'start': 953.199,
#   'duration': 4.961},
#  {'text': 'to good and evil yeah it made you made',
#   'start': 955.839,
#   'duration': 5.281},
#  {'text': 'you realize made me realize that you can',
#   'start': 958.16,
#   'duration': 4.96},
#  {'text': 'sort of in the way in the choices you',
#   'start': 961.12,
#   'duration': 4.0},
#  {'text': 'make can define', 'start': 963.12, 'duration': 3.04},
#  {'text': 'uh the', 'start': 965.12, 'duration': 4.079},
#  {'text': 'where you end up and that means',
#   'start': 966.16,
#   'duration': 5.52},
#  {'text': 'all of us are capable of the good',
#   'start': 969.199,
#   'duration': 5.281},
#  {'text': 'uh evil it all matters in uh the',
#   'start': 971.68,
#   'duration': 4.719},
#  {'text': 'different choices along the trajectory',
#   'start': 974.48,
#   'duration': 3.76},
#  {'text': "to those places that you make it's",
#   'start': 976.399,
#   'duration': 3.921},
#  {'text': 'fascinating i mean games can do that',
#   'start': 978.24,
#   'duration': 3.68},
#  {'text': "philosophically to you and it's rare it",
#   'start': 980.32,
#   'duration': 3.519},
#  {'text': 'seems rare yeah well games are i think a',
#   'start': 981.92,
#   'duration': 4.24},
#  {'text': 'unique medium because um you as the',
#   'start': 983.839,
#   'duration': 3.601},
#  {'text': "player you're not just passively",
#   'start': 986.16,
#   'duration': 4.08},
#  {'text': 'consuming the the entertainment right',
#   'start': 987.44,
#   'duration': 5.28},
#  {'text': "you're actually actively involved as an",
#   'start': 990.24,
#   'duration': 4.88},
#  {'text': "as a as an agent so i think that's what",
#   'start': 992.72,
#   'duration': 3.84},
#  {'text': 'makes it in some ways can be more',
#   'start': 995.12,
#   'duration': 3.36},
#  {'text': 'visceral than other other mediums like',
#   'start': 996.56,
#   'duration': 3.839},
#  {'text': 'you know films and books so the second',
#   'start': 998.48,
#   'duration': 3.68},
#  {'text': 'so that was you know designing ai and',
#   'start': 1000.399,
#   'duration': 4.961},
#  {'text': "games and then the third use uh uh i've",
#   'start': 1002.16,
#   'duration': 5.44},
#  {'text': "we've used of ai is in deep mind from",
#   'start': 1005.36,
#   'duration': 4.399},
#  {'text': 'the beginning which is using games as a',
#   'start': 1007.6,
#   'duration': 5.12},
#  {'text': 'testing ground for proving out ai',
#   'start': 1009.759,
#   'duration': 5.121},
#  {'text': 'algorithms and developing ai algorithms',
#   'start': 1012.72,
#   'duration': 4.88},
#  {'text': 'and that was a that was a sort of um a',
#   'start': 1014.88,
#   'duration': 4.319},
#  {'text': 'core component of our vision at the',
#   'start': 1017.6,
#   'duration': 3.44},
#  {'text': 'start of deepmind was that we would use',
#   'start': 1019.199,
#   'duration': 4.721},
#  {'text': 'games very heavily uh as our main',
#   'start': 1021.04,
#   'duration': 4.879},
#  {'text': 'testing ground certainly to begin with',
#   'start': 1023.92,
#   'duration': 3.84},
#  {'text': "um because it's super efficient to use",
#   'start': 1025.919,
#   'duration': 4.321},
#  {'text': "games and also you know it's very easy",
#   'start': 1027.76,
#   'duration': 5.039},
#  {'text': 'to have metrics to see how well your',
#   'start': 1030.24,
#   'duration': 4.559},
#  {'text': 'systems are improving and what direction',
#   'start': 1032.799,
#   'duration': 3.28},
#  {'text': 'your ideas are going in and whether',
#   'start': 1034.799,
#   'duration': 3.441},
#  {'text': "you're making incremental improvements",
#   'start': 1036.079,
#   'duration': 4.24},
#  {'text': 'and because those games are often rooted',
#   'start': 1038.24,
#   'duration': 3.679},
#  {'text': 'in something that humans did for a long',
#   'start': 1040.319,
#   'duration': 2.961},
#  {'text': 'time beforehand', 'start': 1041.919, 'duration': 3.76},
#  {'text': "there's already a strong", 'start': 1043.28, 'duration': 4.0},
#  {'text': "set of rules like it's already a damn",
#   'start': 1045.679,
#   'duration': 3.681},
#  {'text': "good benchmark yes it's really good for",
#   'start': 1047.28,
#   'duration': 3.92},
#  {'text': "so many reasons because you've got",
#   'start': 1049.36,
#   'duration': 3.52},
#  {'text': "you've got you've got clear measures of",
#   'start': 1051.2,
#   'duration': 4.24},
#  {'text': 'how good humans can be at these things',
#   'start': 1052.88,
#   'duration': 4.159},
#  {'text': "and in some cases like go we've been",
#   'start': 1055.44,
#   'duration': 4.479},
#  {'text': 'playing it for thousands of years um and',
#   'start': 1057.039,
#   'duration': 4.961},
#  {'text': 'and uh often they have scores or at',
#   'start': 1059.919,
#   'duration': 4.401},
#  {'text': "least win conditions so it's very easy",
#   'start': 1062.0,
#   'duration': 3.919},
#  {'text': 'for reward learning systems to get a',
#   'start': 1064.32,
#   'duration': 3.12},
#  {'text': "reward it's very easy to specify what",
#   'start': 1065.919,
#   'duration': 4.64},
#  {'text': 'that reward is um and uh also at the end',
#   'start': 1067.44,
#   'duration': 5.359},
#  {'text': "it's easy to you know to test uh",
#   'start': 1070.559,
#   'duration': 3.921},
#  {'text': 'externally you know', 'start': 1072.799, 'duration': 4.0},
#  {'text': 'how strong is your system by of course',
#   'start': 1074.48,
#   'duration': 3.84},
#  {'text': "playing against you know the world's",
#   'start': 1076.799,
#   'duration': 4.24},
#  {'text': "strongest players at those games so it's",
#   'start': 1078.32,
#   'duration': 4.32},
#  {'text': "it's so good for so many reasons and",
#   'start': 1081.039,
#   'duration': 3.441},
#  {'text': "it's also very efficient to run",
#   'start': 1082.64,
#   'duration': 4.08},
#  {'text': 'potentially millions of simulations in',
#   'start': 1084.48,
#   'duration': 5.12},
#  {'text': 'parallel on the cloud so um i think',
#   'start': 1086.72,
#   'duration': 4.88},
#  {'text': "there's a huge reason why we were so",
#   'start': 1089.6,
#   'duration': 4.24},
#  {'text': 'successful back in you know starting out',
#   'start': 1091.6,
#   'duration': 4.319},
#  {'text': '2010 how come we were able to progress',
#   'start': 1093.84,
#   'duration': 4.959},
#  {'text': "so quickly because we'd utilize games",
#   'start': 1095.919,
#   'duration': 5.041},
#  {'text': 'and um you know at the beginning of deep',
#   'start': 1098.799,
#   'duration': 4.481},
#  {'text': 'mind we also hired some amazing game',
#   'start': 1100.96,
#   'duration': 4.88},
#  {'text': 'engineers uh who i knew from my previous',
#   'start': 1103.28,
#   'duration': 5.44},
#  {'text': 'uh lives in the games industry and uh',
#   'start': 1105.84,
#   'duration': 4.4},
#  {'text': 'and that helped to bootstrap us very',
#   'start': 1108.72,
#   'duration': 4.0},
#  {'text': "quickly and plus it's somehow super",
#   'start': 1110.24,
#   'duration': 4.72},
#  {'text': 'compelling almost at a philosophical',
#   'start': 1112.72,
#   'duration': 5.52},
#  {'text': 'level of man versus machine', 'start': 1114.96, 'duration': 6.079},
#  {'text': 'over over a chessboard or a go board',
#   'start': 1118.24,
#   'duration': 4.559},
#  {'text': 'and especially given that the entire',
#   'start': 1121.039,
#   'duration': 3.441},
#  {'text': 'history of ai is defined by people',
#   'start': 1122.799,
#   'duration': 3.76},
#  {'text': "saying it's going to be impossible to",
#   'start': 1124.48,
#   'duration': 4.0},
#  {'text': 'make a machine that', 'start': 1126.559, 'duration': 4.321},
#  {'text': 'beats a human being in chess', 'start': 1128.48, 'duration': 4.559},
#  {'text': 'and then once that happened', 'start': 1130.88, 'duration': 4.4},
#  {'text': 'people were certain when i was coming up',
#   'start': 1133.039,
#   'duration': 4.161},
#  {'text': 'in ai that go', 'start': 1135.28, 'duration': 3.36},
#  {'text': 'is not a game that could be solved',
#   'start': 1137.2,
#   'duration': 3.92},
#  {'text': 'because of the combinatorial complexity',
#   'start': 1138.64,
#   'duration': 5.52},
#  {'text': "it's just too it's it's it's you know",
#   'start': 1141.12,
#   'duration': 5.439},
#  {'text': "no matter how much moore's law you have",
#   'start': 1144.16,
#   'duration': 4.32},
#  {'text': 'compute is just never going to be able',
#   'start': 1146.559,
#   'duration': 4.721},
# ...
#   'duration': 3.76},
#  {'text': 'enough to you know you might be able to',
#   'start': 1736.64,
#   'duration': 2.8},
#  {'text': 'do that like overnight', 'start': 1737.919, 'duration': 4.721},
#  {'text': 'do you think a game that is optimal',
#   'start': 1739.44,
#   'duration': 5.44},
#  {'text': 'designed by an ai system', 'start': 1742.64, 'duration': 5.039},
#  {'text': 'would look very much like uh planet',
#   'start': 1744.88,
#   'duration': 4.72},
#  {'text': 'earth', 'start': 1747.679, 'duration': 3.921},
#  {'text': "maybe maybe it's only the sort of game i",
#   'start': 1749.6,
#   'duration': 4.319},
#  {'text': "would love to make is is and i've tried",
#   'start': 1751.6,
#   'duration': 4.4},
#  {'text': "you know my in my game's career the",
#   'start': 1753.919,
#   'duration': 4.081},
#  {'text': 'games design career you know my first',
#   'start': 1756.0,
#   'duration': 4.24},
#  {'text': 'big game was designing a theme park an',
#   'start': 1758.0,
#   'duration': 5.039},
#  {'text': 'amusement park then uh with games like',
#   'start': 1760.24,
#   'duration': 4.799},
#  {'text': 'republic i tried to you know have games',
#   'start': 1763.039,
#   'duration': 4.081},
#  {'text': 'where we designed whole cities and and',
#   'start': 1765.039,
#   'duration': 4.321},
#  {'text': 'allowed you to play in so and of course',
#   'start': 1767.12,
#   'duration': 3.76},
#  {'text': 'people like will wright have written',
#   'start': 1769.36,
#   'duration': 3.52},
#  {'text': 'games like sim earth uh trying to',
#   'start': 1770.88,
#   'duration': 3.519},
#  {'text': 'simulate the whole of earth pretty',
#   'start': 1772.88,
#   'duration': 3.84},
#  {'text': "tricky but um i see earth i haven't",
#   'start': 1774.399,
#   'duration': 3.921},
#  {'text': 'actually played that one so what is it',
#   'start': 1776.72,
#   'duration': 3.76},
#  {'text': 'does it incorporative evolution or yeah',
#   'start': 1778.32,
#   'duration': 4.4},
#  {'text': "it has evolution and it's sort of um it",
#   'start': 1780.48,
#   'duration': 3.84},
#  {'text': 'tries to it sort of treats it as an',
#   'start': 1782.72,
#   'duration': 3.28},
#  {'text': 'entire biosphere but from quite a high',
#   'start': 1784.32,
#   'duration': 2.88},
#  {'text': 'level', 'start': 1786.0, 'duration': 2.159},
#  {'text': 'so', 'start': 1787.2, 'duration': 3.199},
#  {'text': 'nice to be able to sort of zoom in zoom',
#   'start': 1788.159,
#   'duration': 4.081},
#  {'text': 'out zoom in exactly so obviously he',
#   'start': 1790.399,
#   'duration': 3.041},
#  {'text': "couldn't do that was in the night i",
#   'start': 1792.24,
#   'duration': 2.799},
#  {'text': 'think he wrote that in the 90s so it',
#   'start': 1793.44,
#   'duration': 2.959},
#  {'text': "couldn't you know it wasn't it wasn't",
#   'start': 1795.039,
#   'duration': 3.36},
#  {'text': 'able to do that but that that would be',
#   'start': 1796.399,
#   'duration': 4.081},
#  {'text': 'uh obviously the ultimate sandbox game',
#   'start': 1798.399,
#   'duration': 2.961},
#  {'text': 'of course', 'start': 1800.48, 'duration': 2.4},
#  {'text': "on that topic do you think we're living",
#   'start': 1801.36,
#   'duration': 3.36},
#  {'text': 'in a simulation', 'start': 1802.88, 'duration': 4.08},
#  {'text': "yes well so okay so i'm gonna jump",
#   'start': 1804.72,
#   'duration': 4.48},
#  {'text': 'around from the absurdly philosophical',
#   'start': 1806.96,
#   'duration': 4.64},
#  {'text': 'to the short term sure very very happy',
#   'start': 1809.2,
#   'duration': 4.24},
#  {'text': 'to so i think uh my answer to that',
#   'start': 1811.6,
#   'duration': 4.16},
#  {'text': 'question is a little bit complex because',
#   'start': 1813.44,
#   'duration': 4.32},
#  {'text': 'uh there is simulation theory which',
#   'start': 1815.76,
#   'duration': 3.68},
#  {'text': 'obviously nick bostrom i think famously',
#   'start': 1817.76,
#   'duration': 3.84},
#  {'text': 'first proposed um', 'start': 1819.44, 'duration': 4.64},
#  {'text': "and uh i don't quite believe it in in",
#   'start': 1821.6,
#   'duration': 5.28},
#  {'text': 'that sense so um in the in the sense',
#   'start': 1824.08,
#   'duration': 4.8},
#  {'text': 'that uh are we in some sort of computer',
#   'start': 1826.88,
#   'duration': 4.799},
#  {'text': 'game or have our descendants somehow',
#   'start': 1828.88,
#   'duration': 5.6},
#  {'text': 'recreated uh uh earth in the you know',
#   'start': 1831.679,
#   'duration': 5.281},
#  {'text': '21st century and and some for some kind',
#   'start': 1834.48,
#   'duration': 5.28},
#  {'text': 'of experimental reason i think that um',
#   'start': 1836.96,
#   'duration': 5.68},
#  {'text': 'but i do think that we that that we',
#   'start': 1839.76,
#   'duration': 4.799},
#  {'text': 'might be that the best way to understand',
#   'start': 1842.64,
#   'duration': 4.88},
#  {'text': 'physics and the universe is from a',
#   'start': 1844.559,
#   'duration': 5.041},
#  {'text': 'computational perspective so', 'start': 1847.52, 'duration': 3.84},
#  {'text': 'understanding it as an information',
#   'start': 1849.6,
#   'duration': 4.4},
#  {'text': 'universe and actually information being',
#   'start': 1851.36,
#   'duration': 6.88},
#  {'text': 'the most fundamental unit of uh reality',
#   'start': 1854.0,
#   'duration': 6.0},
#  {'text': 'rather than matter or energy so a',
#   'start': 1858.24,
#   'duration': 3.6},
#  {'text': 'physicist would say you know matter or',
#   'start': 1860.0,
#   'duration': 3.6},
#  {'text': 'energy you know e equals m c squared',
#   'start': 1861.84,
#   'duration': 3.76},
#  {'text': 'these are the things that are are the',
#   'start': 1863.6,
#   'duration': 3.919},
#  {'text': "fundamentals of the universe i'd",
#   'start': 1865.6,
#   'duration': 4.4},
#  {'text': 'actually say information um which of',
#   'start': 1867.519,
#   'duration': 5.201},
#  {'text': 'course itself can be can specify energy',
#   'start': 1870.0,
#   'duration': 4.559},
#  {'text': 'or matter right matter is actually just',
#   'start': 1872.72,
#   'duration': 3.52},
#  {'text': "you know we're we're just out the way",
#   'start': 1874.559,
#   'duration': 3.441},
#  {'text': 'our bodies and all the molecules in our',
#   'start': 1876.24,
#   'duration': 4.08},
#  {'text': 'body arrange is information so i think',
#   'start': 1878.0,
#   'duration': 4.799},
#  {'text': 'information may be the most fundamental',
#   'start': 1880.32,
#   'duration': 4.64},
#  {'text': 'way to describe the universe and',
#   'start': 1882.799,
#   'duration': 4.401},
#  {'text': "therefore you could say we're in some",
#   'start': 1884.96,
#   'duration': 4.719},
#  {'text': 'sort of simulation because of that um',
#   'start': 1887.2,
#   'duration': 4.16},
#  {'text': "but i don't i do i'm not i'm not really",
#   'start': 1889.679,
#   'duration': 4.24},
#  {'text': 'a subscriber to the idea that um you',
#   'start': 1891.36,
#   'duration': 4.08},
#  {'text': 'know these are sort of throw away',
#   'start': 1893.919,
#   'duration': 3.12},
#  {'text': 'billions of simulations around i think',
#   'start': 1895.44,
#   'duration': 4.16},
#  {'text': 'this is actually very critical and',
#   'start': 1897.039,
#   'duration': 4.88},
#  {'text': 'possibly unique this simulation',
#   'start': 1899.6,
#   'duration': 4.319},
#  {'text': 'particular one yes so but and you just',
#   'start': 1901.919,
#   'duration': 3.281},
#  {'text': 'mean', 'start': 1903.919, 'duration': 3.041},
#  {'text': 'treating the universe', 'start': 1905.2, 'duration': 3.52},
#  {'text': 'as a computer', 'start': 1906.96, 'duration': 2.719},
#  {'text': "that's", 'start': 1908.72, 'duration': 3.439},
#  {'text': 'processing and modifying information',
#   'start': 1909.679,
#   'duration': 4.161},
#  {'text': 'is is a good way to solve the problems',
#   'start': 1912.159,
#   'duration': 5.041},
#  {'text': 'of physics of chemistry of biology',
#   'start': 1913.84,
#   'duration': 6.24},
#  {'text': 'and perhaps of humanity and so on yes i',
#   'start': 1917.2,
#   'duration': 5.68},
#  {'text': 'think understanding physics in terms of',
#   'start': 1920.08,
#   'duration': 5.52},
#  {'text': 'information theory uh might be the best',
#   'start': 1922.88,
#   'duration': 5.12},
#  {'text': "way to to really uh understand what's",
#   'start': 1925.6,
#   'duration': 3.679},
#  {'text': 'going on here', 'start': 1928.0, 'duration': 4.32},
#  {'text': 'from our understanding of a universal',
#   'start': 1929.279,
#   'duration': 5.361},
#  {'text': 'turing machine from our understanding of',
#   'start': 1932.32,
#   'duration': 3.44},
#  {'text': "a computer do you think there's",
#   'start': 1934.64,
#   'duration': 3.68},
#  {'text': 'something outside of the capabilities of',
#   'start': 1935.76,
#   'duration': 4.639},
#  {'text': 'a computer that is present in our',
#   'start': 1938.32,
#   'duration': 4.239},
#  {'text': 'universe you have a disagreement with',
#   'start': 1940.399,
#   'duration': 3.681},
#  {'text': 'roger penrose', 'start': 1942.559, 'duration': 3.761},
#  {'text': 'the nature of consciousness he he thinks',
#   'start': 1944.08,
#   'duration': 3.92},
#  {'text': 'that consciousness is more than just a',
#   'start': 1946.32,
#   'duration': 3.28},
#  {'text': 'computation', 'start': 1948.0, 'duration': 3.6},
#  {'text': 'uh do you think all of it the whole',
#   'start': 1949.6,
#   'duration': 4.319},
#  {'text': 'shebang is can be can be a competition',
#   'start': 1951.6,
#   'duration': 4.079},
#  {'text': "yeah i've had many fascinating debates",
#   'start': 1953.919,
#   'duration': 4.161},
#  {'text': 'with uh sir roger penrose and obviously',
#   'start': 1955.679,
#   'duration': 4.641},
#  {'text': "he's he's famously and i read you know",
#   'start': 1958.08,
#   'duration': 4.64},
#  {'text': 'emperors of new mind and and um',
#   'start': 1960.32,
#   'duration': 4.8},
#  {'text': 'and his books uh his classical books uh',
#   'start': 1962.72,
#   'duration': 3.839},
#  {'text': 'and they they were pretty influential',
#   'start': 1965.12,
#   'duration': 3.76},
#  {'text': 'and you know in the 90s and um he',
#   'start': 1966.559,
#   'duration': 4.0},
#  {'text': "believes that there's something more you",
#   'start': 1968.88,
#   'duration': 4.159},
#  {'text': 'know something quantum that is needed to',
#   'start': 1970.559,
#   'duration': 5.36},
#  {'text': 'explain consciousness in the brain um i',
#   'start': 1973.039,
#   'duration': 4.64},
#  {'text': "think about what we're doing actually at",
#   'start': 1975.919,
#   'duration': 3.76},
#  {'text': 'deepmind and what my career is being',
#   'start': 1977.679,
#   'duration': 4.24},
#  {'text': "we're almost like true rings champion so",
#   'start': 1979.679,
#   'duration': 3.921},
#  {'text': 'we are pushing turing machines or',
#   'start': 1981.919,
#   'duration': 4.161},
#  {'text': 'classical computation to the limits what',
#   'start': 1983.6,
#   'duration': 4.4},
#  {'text': 'are the limits of what classical',
#   'start': 1986.08,
#   'duration': 4.959},
#  {'text': 'computing can do now um and at the same',
#   'start': 1988.0,
#   'duration': 5.679},
#  {'text': "time i've also studied neuroscience to",
#   'start': 1991.039,
#   'duration': 4.48},
#  {'text': "see and that's why i did my phd in was",
#   'start': 1993.679,
#   'duration': 4.161},
#  {'text': 'to see also to look at you know is there',
#   'start': 1995.519,
#   'duration': 3.76},
#  {'text': 'anything quantum in the brain from a',
#   'start': 1997.84,
#   'duration': 3.28},
#  {'text': 'neuroscience or biological perspective',
#   'start': 1999.279,
#   'duration': 4.321},
#  {'text': 'and um and so far i think most',
#   'start': 2001.12,
#   'duration': 3.919},
#  {'text': 'neuroscientists and most mainstream',
#   'start': 2003.6,
#   'duration': 2.959},
#  {'text': 'biologists and neuroscientists would say',
#   'start': 2005.039,
#   'duration': 3.76},
#  {'text': "there's no evidence of any quantum uh",
#   'start': 2006.559,
#   'duration': 4.321},
#  {'text': 'systems or effects in the brain as far',
#   'start': 2008.799,
#   'duration': 3.681},
#  {'text': "as we can see it's it can be mostly",
#   'start': 2010.88,
#   'duration': 4.08},
#  {'text': 'explained by classical uh classical',
#   'start': 2012.48,
#   'duration': 4.559},
#  {'text': 'theories so', 'start': 2014.96, 'duration': 3.92},
#  {'text': "and then so there's sort of the the",
#   'start': 2017.039,
#   'duration': 4.081},
#  {'text': 'search from the biology side and then at',
#   'start': 2018.88,
#   'duration': 4.32},
#  {'text': "the same time there's the raising of the",
#   'start': 2021.12,
#   'duration': 4.799},
#  {'text': 'water uh at the bar from what classical',
#   'start': 2023.2,
#   'duration': 5.68},
#  {'text': 'turing machines can do uh uh and',
#   'start': 2025.919,
#   'duration': 4.801},
#  {'text': 'and you know including our new ai',
#   'start': 2028.88,
#   'duration': 5.12},
#  {'text': 'systems and uh as you alluded to earlier',
#   'start': 2030.72,
#   'duration': 5.679},
#  {'text': 'um you know i think ai especially in the',
#   'start': 2034.0,
#   'duration': 5.12},
#  {'text': 'last decade plus has been a continual',
#   'start': 2036.399,
#   'duration': 5.921},
#  {'text': 'story now of surprising uh events uh and',
#   'start': 2039.12,
#   'duration': 5.6},
#  {'text': 'surprising successes knocking over one',
#   'start': 2042.32,
#   'duration': 4.079},
#  {'text': 'theory after another of what was thought',
#   'start': 2044.72,
#   'duration': 3.76},
#  {'text': 'to be impossible you know from go to',
#   'start': 2046.399,
#   'duration': 5.121},
#  {'text': 'protein folding and so on and so i think',
#   'start': 2048.48,
#   'duration': 4.0},
#  {'text': 'um', 'start': 2051.52, 'duration': 4.559},
#  {'text': 'i would be very hesitant to bet against',
#   'start': 2052.48,
#   'duration': 6.96},
#  {'text': 'how far the uh universal turing machine',
#   'start': 2056.079,
#   'duration': 6.56},
#  {'text': 'and classical computation paradigm can',
#   'start': 2059.44,
#   'duration': 5.84},
#  {'text': 'go and and my betting would be',
#   'start': 2062.639,
#   'duration': 5.121},
#  {'text': "that all of certainly what's going on in",
#   'start': 2065.28,
#   'duration': 5.599},
#  {'text': 'our brain uh can probably be mimicked or',
#   'start': 2067.76,
#   'duration': 5.599},
#  {'text': 'or approximated on a on a classical',
#   'start': 2070.879,
#   'duration': 5.04},
#  {'text': 'machine um not you know not requiring',
#   'start': 2073.359,
#   'duration': 5.121},
#  {'text': 'something metaphysical or quantum and',
#   'start': 2075.919,
#   'duration': 4.321},
#  {'text': "we'll get there with some of the work",
#   'start': 2078.48,
#   'duration': 3.199},
#  {'text': 'with alpha fold', 'start': 2080.24, 'duration': 4.159},
#  {'text': 'which i think begins the journey of',
#   'start': 2081.679,
#   'duration': 4.72},
#  {'text': 'modeling this beautiful and complex',
#   'start': 2084.399,
#   'duration': 4.401},
#  {'text': 'world of biology so you think all the',
#   'start': 2086.399,
#   'duration': 4.881},
#  {'text': 'magic of the human mind comes from this',
#   'start': 2088.8,
#   'duration': 5.359},
#  {'text': 'just a few pounds of mush', 'start': 2091.28, 'duration': 6.079},
#  {'text': 'of a biological computational mush',
#   'start': 2094.159,
#   'duration': 4.081},
#  {'text': "that's", 'start': 2097.359, 'duration': 4.081},
#  {'text': 'akin to some of the neural networks',
#   'start': 2098.24,
#   'duration': 6.24},
#  {'text': 'not directly but in spirit that deep',
#   'start': 2101.44,
#   'duration': 5.12},
#  {'text': 'mind has been working with well look i',
#   'start': 2104.48,
#   'duration': 3.84},
#  {'text': "think it's um you say it's a few you",
#   'start': 2106.56,
#   'duration': 3.36},
#  {'text': "know of course it's this is the i think",
#   'start': 2108.32,
#   'duration': 3.279},
#  {'text': 'the biggest miracle of the universe is',
#   'start': 2109.92,
#   'duration': 4.159},
#  {'text': 'that um it is just a few pounds of mush',
#   'start': 2111.599,
#   'duration': 4.641},
#  {'text': "in our skulls and yet it's also our",
#   'start': 2114.079,
#   'duration': 4.0},
#  {'text': 'brains are the most complex objects in',
#   'start': 2116.24,
#   'duration': 3.92},
#  {'text': 'the in that we know of in the universe',
#   'start': 2118.079,
#   'duration': 3.601},
#  {'text': "so there's something profoundly",
#   'start': 2120.16,
#   'duration': 3.679},
#  {'text': 'beautiful and amazing about our brains',
#   'start': 2121.68,
#   'duration': 2.96},
#  ...]

# %% [markdown]
# # Step 1b - Indexing (Text Splitting)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %% [markdown]
# # Step 1c & 1d - Indexing (Embedding Generation and Storing in Vector Store)

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: 'ebd35c27-6277-4aa8-a7f0-ff6c18c6307e',
#  1: '1d6c5f50-cd89-45b5-9e89-ab6db5e5e47e',
#  2: '0e0c5539-0367-4fd6-bf6f-10819062051f',
#  3: '1c957d0b-160a-435b-bee3-7ede91d109cd',
#  4: 'b0b31d2d-cc09-4826-b184-c29a89d47c2a',
#  5: '2a51ae51-0732-4f0e-9d82-a7a599dba8d5',
#  6: 'ad525777-9c91-40d1-a691-69a17195108a',
#  7: '773e0290-2f6c-4e9f-a54b-63c10e140702',
#  8: '5a2fbd69-0972-43ba-b62c-f21520e98502',
#  9: 'a763e2b3-ff8e-4576-91a7-3a1ec2efd721',
#  10: 'a868697f-a861-4717-a423-9b07830ce261',
#  11: 'b10a0dfa-4c8c-4f18-a4fa-7fc3ebdc5ca0',
#  12: '2dd6e7fd-1aed-43dd-a594-6ddd46336f12',
#  13: 'a97cdc08-d917-4f73-96db-083fe5f0345f',
#  14: '99ed4a22-03b4-463f-ba91-9e168fd49088',
#  15: '6366ef8c-11e7-4dfa-ae94-f3481f4e416f',
#  16: 'f66bebe8-7408-4329-b042-0aebea35b6d0',
#  17: '5f1a298e-aac7-4136-a4bf-1f8724099aa9',
#  18: '65b51d0c-4b52-4fe7-92ca-80df1b57f39d',
#  19: '5e99f97a-ecb3-4010-bc9a-c90d600256fe',
#  20: '4045a3e5-50e7-4305-a7dc-f661231a8f95',
#  21: '38c4776f-2b78-47c2-bd21-72846cae6228',
#  22: '37800099-09e8-4f07-8e5a-c42aa4424da7',
#  23: '90e1f850-a026-4277-98c3-6edf49267b92',
#  24: '216dad33-e72d-4c67-94f4-56394ae88bb2',
#  25: 'b722bba4-c99f-4680-9645-27b5c7fa10c7',
#  26: '9b252ce3-ced5-4133-827d-948f6542ac3b',
#  27: 'd55c4bd8-292b-4942-90e5-43ab6fde01cd',
#  28: '340e138f-6421-4e4b-9aef-bef92ab3b380',
#  29: 'cc691f69-5632-4050-b0ae-e8d500e9e1a0',
#  30: 'c56c60f8-0c79-4a45-b1af-e75a1b5f4b78',
#  31: '76207700-8286-452b-9582-8ea72d5749dd',
#  32: '32ae86ce-758b-4ec4-b045-4dbf045cb90c',
#  33: '9496de8e-5cc5-4b9f-94ca-4a7c49315d91',
#  34: 'db84a1e7-af57-4277-8184-2e0d8bbaaf0c',
#  35: '48377f94-344c-43ea-8925-efc45d073351',
#  36: 'fd5bb435-769f-4968-bb05-69a370fd397f',
#  37: 'a4cfe4af-e16f-4a8a-b0fc-82b025ff9e1c',
#  38: '53c40b7a-3fdd-41f4-9198-3afc43a48493',
#  39: '4b5f369a-4403-42f4-b4fb-b646e1cb74c7',
#  40: 'ce8c6f85-39af-46d3-99fc-11e0f0ad0c27',
#  41: 'edd011eb-5399-4576-b31f-2bc6af7ea135',
#  42: '19315132-133b-40e1-98ff-b091a3d5df04',
#  43: '46f3a130-50d5-4aca-b8b3-f5704a8c05e7',
#  44: 'a178cec4-ca06-4389-91d2-bbbd292ea38a',
#  45: '332d3817-9a9f-421e-9f05-21ca66fd1f5b',
#  46: 'ea7c0eb9-4eb5-4ac0-86d3-2cd424650df9',
#  47: 'fa124131-730c-406f-837b-d8141d5fa127',
#  48: '0e61e3c1-12cc-462a-9e9a-9030070618f7',
#  49: 'e8be7131-c36b-49ec-b51a-73b1da1a6228',
#  50: 'f4d5b4cd-87d2-4331-a8e3-9fa26cf1b71d',
#  51: 'ecbe0bff-28e3-4bd5-99ef-233f3014d243',
#  52: 'd9326375-f4ab-470b-a0e4-7176507a14e4',
#  53: '5d332f22-7d72-42ed-9724-38353c963b85',
#  54: 'd7d236bc-7bb1-4991-a22e-f7f262c22586',
#  55: '9aa053b6-abae-4ec3-a7b2-3fd48c667bcf',
#  56: '668aceff-bf37-4855-829a-13ab97739ec0',
#  57: '9e664af5-b339-4b5b-abbf-a7ab8826f766',
#  58: 'b108a115-3e85-4a4a-924d-f325b5ec74aa',
#  59: '032bc572-b7f6-4821-9d88-30a3b31f904c',
#  60: '88367845-c5ab-41be-a9e3-adec30f1c4d9',
#  61: '141ae60b-ed5f-432d-a8bb-1860daf85df5',
#  62: '3d9e4b40-7c9c-47ea-92dc-f05bf4593283',
#  63: '7a336991-bb6d-43dd-ac00-4058cff767f5',
#  64: '833cad48-4bc7-46c6-ad97-ff8dcfa28ac4',
#  65: '17e0695d-5d0f-45f4-9c49-4dcb8437d017',
#  66: '79c24af7-82d1-447b-90b5-cf521d2f726f',
#  67: '2c843c1c-beed-4088-bd1b-a9c3a6f34155',
#  68: 'fcf9768c-9303-4dcd-9ff8-526688fa0c47',
#  69: '816384db-7386-48dc-830d-cfebd8246bf2',
#  70: '078b032d-9e0c-4ba4-bc68-8a1bd706ee28',
#  71: '35cfbdfc-e310-4e35-b4ae-6a639ac8c518',
#  72: '30965ede-e105-402c-9afc-6701322e58f8',
#  73: '557e8878-bbfe-44dc-872d-8eec060a0c66',
#  74: '826fa86f-82e5-44ec-8f81-b7fdd80e2270',
#  75: 'd60452f6-9f8e-4f74-83eb-c3cb5879677b',
#  76: '13989492-5ff8-4eb2-bef8-6fe8cacb15dd',
#  77: 'abdb7fd5-b378-4c1f-963f-e5d2970e5dd8',
#  78: '32d5806d-969f-4ab1-a327-cb5b88a543c2',
#  79: 'a171bde7-6796-4f62-a810-b402b1063d78',
#  80: '2697ac90-a5e5-4967-a195-70c1c7d9ce41',
#  81: '8a4b5f04-c226-47fc-935a-15aeec5b892a',
#  82: 'd243dbb0-b9fe-4b3f-9cd0-e997da08b67a',
#  83: '33471b3e-c196-4460-8bce-bb0094fc74ee',
#  84: '7f988f88-2d26-4d00-a8cd-75bff602d60c',
#  85: '16d3b976-9622-4384-b983-d85b38c26df7',
#  86: '78ab8f7a-efcf-4bfc-acee-d2e2596f2d27',
#  87: 'de7fe936-f607-485a-a05c-695ae52f1b80',
#  88: 'b0d939b7-5be2-4814-b410-d73e562a3f0a',
#  89: '3b2e78fe-0c58-46cb-a933-a4626331cb8c',
#  90: 'e16cc865-65ad-4d6f-9ed6-3d8c6acffe46',
#  91: 'ef945070-c237-4d75-bb77-e9972d35560f',
#  92: 'f050834d-d366-4623-8431-18e69ab30740',
#  93: '26e9460b-1740-4254-ad59-5516c992a5a7',
#  94: 'c9a225fa-c055-4074-aa5c-6162a365bef8',
#  95: 'bb48c9f7-3079-408a-bc9b-518dbba07a60',
#  96: '152b84a1-7b67-4033-8b86-8a74549dae88',
#  97: 'e3d26d0f-4976-434e-82d5-be83041856aa',
#  98: 'cb46068d-443e-4d8c-b376-a2c4f6b3dd79',
#  99: '3a1883ab-c1ea-48ac-a6f6-add97a06bfaf',
#  100: 'f594e02e-64bb-44cb-a003-7c7952bba2f4',
#  101: 'f09f951c-aee3-49b0-8f17-3cfa51066776',
#  102: '29664486-58a5-4fd7-aa5d-b0029972d810',
#  103: 'b8d409a6-098e-4e45-90ee-ee237890ec96',
#  104: '0164c1e8-5218-4b41-b96a-982516686432',
#  105: 'd1e0f683-f8cc-4dbb-95ae-678483b58110',
#  106: '7bb082a1-7c8b-4ce6-99fc-70e5d11f6c9e',
#  107: '8ad8f026-97b3-43c8-b70c-975503974c2f',
#  108: 'e73c9263-07b7-4a99-bf42-57ad08a0b9d7',
#  109: '5abe232b-c12e-43ac-95d2-be9d02f589e3',
#  110: 'a792271c-c7f3-4774-b972-ccc61116a04b',
#  111: 'cf89607c-6ad6-4259-9eff-9884dac90605',
#  112: '3b1f9ef2-304a-4bda-b24f-861c79e7a823',
#  113: 'd863195f-44b0-46d7-af34-1be7013b706b',
#  114: '102cbd77-22a6-46ac-ac6f-177d103eb2a5',
#  115: 'e3e839b2-87eb-45c6-9790-d56c2ad7f896',
#  116: 'f7d52600-1d86-483e-b56b-c069a9accac5',
#  117: '979684ff-4605-4f53-8b96-1e5246aa0678',
#  118: '94cc1cdb-4d68-420f-91d2-962018357c24',
#  119: '897c8893-a3f0-42b5-8737-47f2f7a72f6a',
#  120: '44425d5b-f10a-4681-8d64-9b35aa1f8387',
#  121: '22788179-6ed2-469a-b14e-3df11bb6280e',
#  122: '50ab1a48-df68-4b31-9ef3-b88fa45ae541',
#  123: 'aaa5aa32-5753-468c-a79b-66bd26c25798',
#  124: 'b6336e1d-253f-475a-bde0-7382d15c2c25',
#  125: 'c49c9868-09ff-4e54-baf7-beeb2ba52d21',
#  126: 'a97a8919-56d5-453d-b42c-1decb6ed88ad',
#  127: 'facbbbbc-7bd4-4f6f-9cfd-6056c758b530',
#  128: 'd70df7ee-cbd6-4374-85dc-aa70523bfc5b',
#  129: '105bcc79-20c8-47e4-864b-d2809749e180',
#  130: '625972b2-2a4b-4d89-a0b5-6335a36fc785',
#  131: 'f1fd02b3-39e7-48e4-bf10-d2de1c157832',
#  132: '86d01e66-1278-4b7d-adbd-344e69b9fd6c',
#  133: '5d4a5b89-c82e-4dfa-813a-f49dadd14a08',
#  134: 'a783076b-5102-4492-bc5b-5ec6a1b0616d',
#  135: 'ad57cb1a-b51b-4c6c-aba8-3a1647bd467a',
#  136: '1c044d7b-ee31-4a75-a6cd-7c41f41df120',
#  137: '17409ca5-4992-4c52-b011-e7f97d42b375',
#  138: 'fd00a469-b02a-4e6e-adf3-452c84ca0813',
#  139: '9766787d-2ba7-4081-9a0c-b5824df9e3af',
#  140: '28963dbb-99d7-4572-868c-b779ea429729',
#  141: 'b424e31b-e0c2-40b7-b161-ad87c613ce9c',
#  142: '5737f568-6343-4e54-b623-8df5b1fc8e66',
#  143: '6364162b-6a08-4080-ae8c-1386b48cb884',
#  144: '823a44da-4fda-4bcc-b4bb-a1919bccd1b7',
#  145: 'b6888bcd-b5e8-4901-af7c-460674ceadb6',
#  146: 'b46a381e-6566-4ebe-84ce-91e8ddf1b8b7',
#  147: '076bf101-a999-4f30-977f-019cf6ed3a8c',
#  148: '5dab1aac-f1d5-411e-a542-be2dfe3b0531',
#  149: '9f8e731e-d21c-4508-af8e-47f280e68477',
#  150: 'c9618973-46d0-49b8-b9d8-64dfdb277fc4',
#  151: '13a5166a-0766-45c0-91c7-f960fe1b4d8e',
#  152: 'a7751437-259c-4f96-9b1e-faa22e06a711',
#  153: '13d240d0-51f3-4a82-9a75-c4685dbe5b4f',
#  154: '5c79a4ae-8a2a-4d91-b098-fabf6d78785c',
#  155: 'ee2e77cb-90fd-4e14-86ec-b178fb811894',
#  156: '3053feeb-78be-41c7-b760-97ced3978f26',
#  157: '182df5af-77f1-4e38-a4b4-08acbc3a742c',
#  158: '531b1a9f-0e8f-4f15-b77d-6891e93097d8',
#  159: '1664b9d2-7ce3-4f7e-b664-1f2ec51ad549',
#  160: '0b3156c9-eb3c-4f14-84fb-f4b04984491f',
#  161: '1c08abf0-6a10-496a-a183-6cc969791dc0',
#  162: 'e3855b30-7918-484b-a1f2-f2d4a6a8cd61',
#  163: '5447d472-fd1c-4cbd-bd58-adc8e5813873',
#  164: '8632cbd1-a1e7-444a-9485-8b60ca2ed772',
#  165: '9ed4202c-20da-4664-b0a1-3b4256629e13',
#  166: '5a7d3516-fe59-430f-ab7c-5162a84f9a1a',
#  167: 'f1b94b86-7212-4081-a8c9-64886e3580d4'}

# %%
vector_store.get_by_ids(['3b1f9ef2-304a-4bda-b24f-861c79e7a823'])
# Out:
# [Document(id='3b1f9ef2-304a-4bda-b24f-861c79e7a823', metadata={}, page_content="the music yourself so i think we see this in all forms of life so it'll be that times you know a million but it would you can imagine also one sign of intelligence is the ability to explain things clearly and simply right you know people like richard feynman another one of my all-time heroes used to say that right if you can't you know if you can explain it something simply then you that's a that's the best sign a complex topic simply then that's one of the best signs of you understanding it yeah so i can see myself talking trash in the ai system in that way yes uh it gets frustrated how dumb i am and trying to explain something to me i was like well that means you're not intelligent because if you were intelligent you'd be able to explain it simply yeah of course you know there's also the other option of course we could enhance ourselves and and without devices we we are already sort of symbiotic with our compute devices right with our phones and other things and you know this stuff")]

# %% [markdown]
# # Step 2 - Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x78080f9d5d90>, search_kwargs={'k': 4})

# %%
retriever.invoke("Who is demus hasabis")
# Out:
# [Document(id='ebd35c27-6277-4aa8-a7f0-ff6c18c6307e', metadata={}, page_content="the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough"),
#  Document(id='5a7d3516-fe59-430f-ab7c-5162a84f9a1a', metadata={}, page_content="deeper maybe simpler explanation yes of things right than the standard model of physics which we know doesn't work but we still keep adding to so um and and that's how i think the beginning of an explanation would look and it would start encompassing many of the mysteries that we have wondered about for thousands of years like you know consciousness uh life and gravity all of these things yeah giving us a glimpses of explanations for those things yeah well um damas dear one of the special human beings in this giant puzzle of ours and it's a huge honor that you would take a pause from the bigger puzzle to solve this small puzzle of a conversation with me today it's truly an honor and a pleasure thank you thank you i really enjoyed it thanks lex thanks for listening to this conversation with demas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than"),
#  Document(id='f1b94b86-7212-4081-a8c9-64886e3580d4', metadata={}, page_content='demas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than astronomy is about telescopes thank you for listening and hope to see you next time'),
#  Document(id='1d6c5f50-cd89-45b5-9e89-ab6db5e5e47e', metadata={}, page_content="out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough to interview you well i'll be impressed if if you were i'd be impressed by myself if you were i don't think we're quite up to that yet but uh maybe you're from the future lex if you did would you tell me is that is that a good thing to tell a language model that's tasked with interviewing that it is in fact um ai maybe we're in a kind of meta turing test uh probably probably it would be a good idea not to tell you so it doesn't change your behavior right this is a kind of heisenberg uncertainty principle situation if i told you you behave differently yeah maybe that's what's happening with us of course this is a benchmark from the future where they replay 2022 as a year before ais were good enough yet and now we want to see is it going to pass exactly if i was such a program would you be")]

# %% [markdown]
# # Step 3 - Augmentation

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)

# %%
prompt = PromptTemplate(
    template="""
    You are an helpful assitance.
    answer only from provided transcript context.
    if the content is insufficient just say i dont know

    {context}
    Question:{question}
    """,
    input_variables=["context", "question"]
)

# %%
question = "what about alien"
retrieved_docs = retriever.invoke(question)

# %%
for doc in retrieved_docs:
  print(doc.page_content)
# Out:
# thoughts it could be some interactions with our mind that we think are originating from us is actually something that uh is coming from other life forms elsewhere consciousness itself might be that it could be but i don't see any sensible argument to the why why would all of the alien species be using this way yes some of them will be more primitive they would be close to our level you know there would there should be a whole sort of normal distribution of these things right some would be aggressive some would be you know curious others would be very stoical and philosophical because you know maybe they're a million years older than us but it's not it shouldn't be like what i mean one one alien civilization might be like that communicating thoughts and others but i don't see why you know potentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music]
# other option of course we could enhance ourselves and and without devices we we are already sort of symbiotic with our compute devices right with our phones and other things and you know this stuff like neural link and etc that could be could could advance that further um so i think there's lots of lots of really amazing possibilities uh that i could foresee from here well let me ask you some wild questions so out there looking for friends do you think there's a lot of alien civilizations out there so i guess this also goes back to your origin of life question too because i think that that's key um my personal opinion looking at all this and and you know it's one of my hobbies physics i guess so so i i you know it's something i think about a lot and talk to a lot of experts on and and and read a lot of books on and i think my feeling currently is that that we are alone i think that's the most likely scenario given what what evidence we have so um and the reasoning is i think that you
# space age we should have heard a cacophony of voices we should have joined that cacophony of voices and what we did we opened our ears and we heard nothing and many people who argue that there are aliens would say well we haven't really done exhaustive search yet and maybe we're looking in the wrong bands and and we've got the wrong devices and we wouldn't notice what an alien form was like to be so different to what we're used to but you know i'm not i don't really buy that that it shouldn't be as difficult as that like we i think we've searched enough there should be if it were everywhere if it was it should be everywhere we should see dyson's fears being put up sun's blinking in and out you know there should be a lot of evidence for those things and then there are other people argue well the sort of safari view of like well we're a primitive species still because we're not space faring yet and and and we're you know there's some kind of globe like universal rule not to interfere
# potentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music] gain the ability to be destructive an order of magnitude more destructive but of course the the sad thought well either humans are very special we took a lot of leaps that arrived at what it means to be human yeah um there's a question there which was the hardest which was the most special but also if others have reached this level and maybe many others have reached this level the great filter that prevented them from going farther to becoming a multi-planetary species or reaching out into the stars and those are really important questions for us whether um whether there's other alien civilizations out there or not this is very useful for us to think about if we destroy ourselves how will we do it and how easy is it to do yeah well you know these are big questions and i've thought about

# %%
context_text = "\n\n".join(docs.page_content for docs in retrieved_docs)
context_text
# Out:
# "thoughts it could be some interactions with our mind that we think are originating from us is actually something that uh is coming from other life forms elsewhere consciousness itself might be that it could be but i don't see any sensible argument to the why why would all of the alien species be using this way yes some of them will be more primitive they would be close to our level you know there would there should be a whole sort of normal distribution of these things right some would be aggressive some would be you know curious others would be very stoical and philosophical because you know maybe they're a million years older than us but it's not it shouldn't be like what i mean one one alien civilization might be like that communicating thoughts and others but i don't see why you know potentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music]\n\nother option of course we could enhance ourselves and and without devices we we are already sort of symbiotic with our compute devices right with our phones and other things and you know this stuff like neural link and etc that could be could could advance that further um so i think there's lots of lots of really amazing possibilities uh that i could foresee from here well let me ask you some wild questions so out there looking for friends do you think there's a lot of alien civilizations out there so i guess this also goes back to your origin of life question too because i think that that's key um my personal opinion looking at all this and and you know it's one of my hobbies physics i guess so so i i you know it's something i think about a lot and talk to a lot of experts on and and and read a lot of books on and i think my feeling currently is that that we are alone i think that's the most likely scenario given what what evidence we have so um and the reasoning is i think that you\n\nspace age we should have heard a cacophony of voices we should have joined that cacophony of voices and what we did we opened our ears and we heard nothing and many people who argue that there are aliens would say well we haven't really done exhaustive search yet and maybe we're looking in the wrong bands and and we've got the wrong devices and we wouldn't notice what an alien form was like to be so different to what we're used to but you know i'm not i don't really buy that that it shouldn't be as difficult as that like we i think we've searched enough there should be if it were everywhere if it was it should be everywhere we should see dyson's fears being put up sun's blinking in and out you know there should be a lot of evidence for those things and then there are other people argue well the sort of safari view of like well we're a primitive species still because we're not space faring yet and and and we're you know there's some kind of globe like universal rule not to interfere\n\npotentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music] gain the ability to be destructive an order of magnitude more destructive but of course the the sad thought well either humans are very special we took a lot of leaps that arrived at what it means to be human yeah um there's a question there which was the hardest which was the most special but also if others have reached this level and maybe many others have reached this level the great filter that prevented them from going farther to becoming a multi-planetary species or reaching out into the stars and those are really important questions for us whether um whether there's other alien civilizations out there or not this is very useful for us to think about if we destroy ourselves how will we do it and how easy is it to do yeah well you know these are big questions and i've thought about ...

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n    You are an helpful assitance.\n    answer only from provided transcript context.\n    if the content is insufficient just say i dont know\n\n    thoughts it could be some interactions with our mind that we think are originating from us is actually something that uh is coming from other life forms elsewhere consciousness itself might be that it could be but i don't see any sensible argument to the why why would all of the alien species be using this way yes some of them will be more primitive they would be close to our level you know there would there should be a whole sort of normal distribution of these things right some would be aggressive some would be you know curious others would be very stoical and philosophical because you know maybe they're a million years older than us but it's not it shouldn't be like what i mean one one alien civilization might be like that communicating thoughts and others but i don't see why you know potentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music]\n\nother option of course we could enhance ourselves and and without devices we we are already sort of symbiotic with our compute devices right with our phones and other things and you know this stuff like neural link and etc that could be could could advance that further um so i think there's lots of lots of really amazing possibilities uh that i could foresee from here well let me ask you some wild questions so out there looking for friends do you think there's a lot of alien civilizations out there so i guess this also goes back to your origin of life question too because i think that that's key um my personal opinion looking at all this and and you know it's one of my hobbies physics i guess so so i i you know it's something i think about a lot and talk to a lot of experts on and and and read a lot of books on and i think my feeling currently is that that we are alone i think that's the most likely scenario given what what evidence we have so um and the reasoning is i think that you\n\nspace age we should have heard a cacophony of voices we should have joined that cacophony of voices and what we did we opened our ears and we heard nothing and many people who argue that there are aliens would say well we haven't really done exhaustive search yet and maybe we're looking in the wrong bands and and we've got the wrong devices and we wouldn't notice what an alien form was like to be so different to what we're used to but you know i'm not i don't really buy that that it shouldn't be as difficult as that like we i think we've searched enough there should be if it were everywhere if it was it should be everywhere we should see dyson's fears being put up sun's blinking in and out you know there should be a lot of evidence for those things and then there are other people argue well the sort of safari view of like well we're a primitive species still because we're not space faring yet and and and we're you know there's some kind of globe like universal rule not to interfere\n\npotentially the hundreds there should be would be uniform in this way right it could be a violent dictatorship that the the people the alien civilizations that uh become successful become um [Music] gain the ability to be destructive an order of magnitude more destructive but of course the the sad thought well either humans are very special we took a lot of leaps that arrived at what it means to be human yeah um there's a question there which was the hardest which was the most special but also if others have reached this level and maybe many others have reached this level the great filter that prevented them from going farther to becoming a multi-planetary species or reaching out into the stars and those are really important questions for us whether um whether there's other alien civilizations out there or not  ...

# %% [markdown]
# # Step 4 - Generation

# %%
answer = llm.invoke(final_prompt)

# %%
print(answer.content)
# Out:
# The discussion suggests that there may be many alien civilizations, but the speaker personally believes that we are likely alone based on the evidence available. They argue that we should have heard signs of other civilizations by now, and the lack of evidence leads them to think that if aliens were everywhere, we would have noticed. They also mention the possibility of different types of alien civilizations, ranging from primitive to advanced, but question why they would all communicate in a similar way. The speaker reflects on the idea that if other civilizations exist, they may face challenges that prevent them from becoming multi-planetary or reaching out into the stars.

# %% [markdown]
# # Building a **Chain**

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough,RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  return "\n\n".join(docs.page_content for docs in retrieved_docs)

# %%
paralle_chain = RunnableParallel(
    context=retriever | RunnableLambda(format_docs),
    question=RunnablePassthrough()
)

# %%
paralle_chain.invoke("who is demis")
# Out:
# {'context': "the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough\n\ndeeper maybe simpler explanation yes of things right than the standard model of physics which we know doesn't work but we still keep adding to so um and and that's how i think the beginning of an explanation would look and it would start encompassing many of the mysteries that we have wondered about for thousands of years like you know consciousness uh life and gravity all of these things yeah giving us a glimpses of explanations for those things yeah well um damas dear one of the special human beings in this giant puzzle of ours and it's a huge honor that you would take a pause from the bigger puzzle to solve this small puzzle of a conversation with me today it's truly an honor and a pleasure thank you thank you i really enjoyed it thanks lex thanks for listening to this conversation with demas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than\n\nout our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough to interview you well i'll be impressed if if you were i'd be impressed by myself if you were i don't think we're quite up to that yet but uh maybe you're from the future lex if you did would you tell me is that is that a good thing to tell a language model that's tasked with interviewing that it is in fact um ai maybe we're in a kind of meta turing test uh probably probably it would be a good idea not to tell you so it doesn't change your behavior right this is a kind of heisenberg uncertainty principle situation if i told you you behave differently yeah maybe that's what's happening with us of course this is a benchmark from the future where they replay 2022 as a year before ais were good enough yet and now we want to see is it going to pass exactly if i was such a program would you be\n\ndemas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than astronomy is about telescopes thank you for listening and hope to see you next time",
#  'question': 'who is demis'}

# %%
parser = StrOutputParser()

# %%
main_chain = paralle_chain | prompt | llm | parser

# %%
main_chain.invoke("about alien? and give me the answer in a list format")
# Out:
# '1. The speaker believes that we are likely alone in the universe, based on current evidence.\n2. They think that if there were many alien civilizations, we should have heard a "cacophony of voices" by now.\n3. The speaker argues that the search for extraterrestrial life has been extensive enough to expect some evidence if it existed.\n4. They mention that alien civilizations could vary greatly, with some being primitive and others potentially more advanced or aggressive.\n5. The idea of a "great filter" is introduced, suggesting that there may be barriers preventing civilizations from advancing to a multi-planetary stage or reaching out into the stars.\n6. The speaker emphasizes the importance of considering these questions, especially regarding humanity\'s potential self-destruction.'
